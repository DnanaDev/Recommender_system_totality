# %% [markdown]
# # Requirements of Totality  Corp:
# <b>Assignment 1 </b><br>(Design Recommendation System Architecture)<br>
# Content discovery is a vital part for the Yovo. Users often don't know what they want to watch and need a way to discover content without searching for it. <b>Create a feed personalisation algorithm strategy which enables users to discover the right content. Underlying algorithm must strike an elegant balance between Machine Learning and giving the user control over what content they want to see.</b>
# Note:
# - Video has certain text attributes: tags, category, title text (context) - Use pseudocode wherever necessary
# - Download ​yovo app​ to see actual feed

# %% [markdown]
# # Potential solutions to the problem:
#
# ### Recommender Systems generally follow one of two methods:
# ##### 1. Collaborative filtering
#
# This approach <b> will not apply to the Yovo app as there is no option for users to like certain videos in their feed.
# The approach would require the app to keep track of each user and their likes, shares etc. in the form of user matrix. </b>
#
#
# ##### 2. Content Based filtering (Suitable for YOVO app)
#
# This approach utilizes a series of discrete characteristics of an item in order to recommend additional items with similar properties.
#
# <b>Based on items,which are videos in the case of Yovo including the characteristics - tags, category, title text (context) in this case.
#
# This method is suitable in the case where metadata is available and no matrix of users ids, preferences is available.</b>

# %% [markdown]
# # Practical Example of Content based filtering (Architecture) :
#
# ## The Dataset
#
# The dataset of 500 entries of different items like shoes, shirts etc., along with an item-id and a <b>textual description of the item.</b><br>
# The system creates a profile for each item and recommends similar items.
#
# <b>For totality, I imagine this dataset will be replaced with one containing textual discription of the video(videoId)
# using the tags or title  attributes.</b>
#
# ## Process
#
# #### 1. Extract TF * IDF [(term frequency)*(Inverse document frequency)] Score
#
# The TF*IDF algorithm finds the importance of a word in the tag. This is done for each word in the tag and for each item.<br>
# <b>This is implemented using scikit-learns inbuilt TF-IDF vectorizer. </b>
#
# #### 2. Calculating Similarity using Cosine Similarity
# Once we have the vectors for each item, we can use cosine similarity to find items/ words that are similar.<br>
# Cosine similarity judges how close the cosine angles are in the vector representation of the items.<br>
#
# <b>This is done using the linear_kernel method of scikit-learn. It takes the tfidf matrix of the items as input and compares them to find items that are similar. </b>
#
# #### 3. Store results of cosine similarity
# The results of cosine similarity are stored in result, arranged according to similarity with item i.
#
# #### 4. Recommending Items
# The function recommend takes in the item for which a recommendation is to be made and the number of recommmendations to be made and reads out the most similar items from results.
# <br>
# We input a threshold value to only get recommendation above a certain similarity index.<br>
# <b> The items recommended can then be fed into the personalized feed of the user for relevant video recommendations.</b>

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel,cosine_similarity 

# reads dataset 
ds = pd.read_csv("sample-data.csv")

ds.head()

# 1. calculates tf-idf scores for items
tf = TfidfVectorizer(analyzer='word', ngram_range=(1, 3), min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(ds['description'])


# 2. Calculate cosine similarity 
cosine_similarities = cosine_similarity(tfidf_matrix, tfidf_matrix) 
results = {}

# 3. Saving results in order of similarity to item i to dictionary results

for idx, row in ds.iterrows():
    similar_indices = cosine_similarities[idx].argsort()[:-100:-1]
    similar_items = [(cosine_similarities[idx][i], ds['id'][i]) for i in similar_indices]

    results[row['id']] = similar_items[1:]

print('Saved')

def item(id):
    return ds.loc[ds['id'] == id]['description'].tolist()[0].split(' - ')[0]

# 4.a Just reads the results out of the dictionary.
def recommend(item_id, num, threshold):
    print("Recommending " + str(num) + " products similar to " + item(item_id) + " with threshold " + str(threshold) + "...")
    print("-------")
    recs = results[item_id][:num]
    for rec in recs:
        
        # A condition can be added to only to print items above a similairty threshold (50% etc.)
        if(rec[0]>threshold):
            print("Recommended: " + item(rec[1]) + " (score:" + str(rec[0]) + ")")

# 4. Recommend items similar to item_id and num = number of recommendations with a similarity threshold value 


recommend(item_id=9, num=5, threshold= 0.3)  # Recommend  5 items similar to item_id 9 with similarity of >30%
print('')
print('')
print('')
recommend(item_id=22, num=10, threshold= 0.5) # Recommend  10 items similar to item_id 22 with similarity of >50%
for itemid in range(1,500):
    print('')
    print('')
    recommend(item_id=itemid, num=10, threshold= 0.2)
    print('')
    print('')
# Out:
# Saved
# Recommending 5 products similar to Baby micro d-luxe cardigan with threshold 0.3...
# -------
# Recommended: Micro d-luxe cardigan (score:0.37550840843454386)
#
#
#
# Recommending 10 products similar to Cap 2 t-shirt with threshold 0.5...
# -------
# Recommended: Cap 2 crew (score:0.7049890803634628)
# Recommended: Cap 2 t-shirt (score:0.7041906217524192)
# Recommended: Cap 2 cap sleeve (score:0.6635362790007221)
# Recommended: Cap 2 zip neck (score:0.6225162259563579)
# Recommended: Cap 2 zip neck (score:0.5295225236280278)
# Recommended: Cap 2 v-neck (score:0.5094581638236435)
#
#
# Recommending 10 products similar to Active classic boxers with threshold 0.2...
# -------
# Recommended: Cap 1 boxer briefs (score:0.2203792147261746)
#
#
#
#
# Recommending 10 products similar to Active sport boxer briefs with threshold 0.2...
# -------
# Recommended: Active sport briefs (score:0.4181663992161582)
#
#
#
#
# Recommending 10 products similar to Active sport briefs with threshold 0.2...
# -------
# Recommended: Active sport boxer briefs (score:0.4181663992161582)
#
#
#
#
# Recommending 10 products similar to Alpine guide pants with threshold 0.2...
# -------
# Recommended: Alpine guide pants (score:0.8253856759948807)
# Recommended: Guide jkt (score:0.20769755384994895)
#
#
#
#
# Recommending 10 products similar to Alpine wind jkt with threshold 0.2...
# -------
# Recommended: Alpine wind jkt (score:0.9550036493156143)
#
#
#
#
# Recommending 10 products similar to Ascensionist jkt with threshold 0.2...
# -------
# Recommended: Guide jkt (score:0.30190056179945784)
# Recommended: Guide jkt (score:0.29311944514467836)
#
#
#
#
# Recommending 10 products similar to Atom with threshold 0.2...
# -------
# Recommended: Single shot (score:0.2662682323077333)
# Recommended: Pocket pack (score:0.2549889349464077)
# Recommended: Hip pack (score:0.2545734766061306)
# Recommended: Daily grind (score:0.24263133914701276)
# Recommended: Lightwire brief (score:0.23121790250236796)
# Recommended: Lightwire (score:0.22238832482586932)
# Recommended: Lw travel sling (score:0.21179521603176457)
# Recommended: Crosstown (score:0.20446199842679574)
#
#
#
#
# Recommending 10 products similar to Print banded betina btm with threshold 0.2...
# -------
# Recommended: Solid betina btm (score:0.9132682180464679)
# Recommended: Print sunamee btm (score:0.44936373433197635)
# Recommended: Solid sunamee btm (score:0.44620637521065026)
# Recommended: Print adour btm (score:0.38174009592040015)
# Recommended: Print bayonne btm (score:0.3692992879122715)
# Recommended: Solid adour btm (score:0.36814059567324636)
# Recommended: Print paries btm (score:0.335665677801261)
# Recommended: Solid paries btm (score:0.3287359918429554)
# Recommended: Solid bibiana 1 piece (score:0.2892598152540898)
# Recommended: Print bibiana tankini (score:0.2591840255496122)
#
#
#
#
# Recommending 10 products similar to Baby micro d-luxe cardigan with threshold 0.2...
# -------
# Recommended: Micro d-luxe cardigan (score:0.37550840843454386)
#
#
#
#
# Recommending 10 products similar to Baby sun bucket hat with threshold 0.2...
# -------
# Recommended: Trim brim hat (score:0.3024706023342056)
# Recommended: Baby baggies shorts (score:0.2166252228693151)
#
#
#
#
# Recommending 10 products similar to Baby sunshade top with threshold 0.2...
# -------
# Recommended: Sunshade hoody (score:0.21330296021085057)
#
#
#
#
# Recommending 10 products similar to Baggies shorts with threshold 0.2...
# -------
# Recommended: River shorts (score:0.2465338617725097)
#
#
#
#
# Recommending 10 products similar to Beach bucket with threshold 0.2...
# -------
#
#
#
#
# Recommending 10 products similar to Better sweater jkt with threshold 0.2...
# -------
# Recommended: Better sweater jkt (score:0.3820941190210234)
#
#
#
#
# Recommending 10 products similar to Borderless shorts-11 in. with threshold 0.2...
# -------
# Recommended: Borderless shorts-7 in. (score:0.5292087918224067)
# Recommended: Borderless trek pants (score:0.4000318829835315)
# Recommended: Borderless messenger shorts (score:0.39590724149738954)
# Recommended: Borderless trek zip-off pants (score:0.3914341729774648)
# Recommended: Borderless gi shorts (score:0.20850892691071193)
# Recommended: Borderless shorts (score:0.2023275385315686)
#
#
#
#
# Recommending 10 products similar to Borderless shorts-7 in. with threshold 0.2...
# -------
# Recommended: Borderless shorts-11 in. (score:0.5292087918224067)
# Recommended: Borderless trek pants (score:0.4112760613436212)
# Recommended: Borderless messenger shorts (score:0.40762233939622655)
# Recommended: Borderless trek zip-off pants (score:0.3839531725451692)
# Recommended: Borderless gi shorts (score:0.211977553456227)
# Recommended: Borderless shorts (score:0.2067458249397682)
#
#
#
#
# Recommending 10 products similar to Bucket hat with threshold 0.2...
# -------
#
#
#
#
# Recommending 10 products similar to Cap 1 bottoms with threshold 0.2...
# -------
# Recommended: Cap 1 bottoms (score:0.5651753677668032)
# Recommended: Cap 1 t-shirt (score:0.48930235404068384)
# Recommended: Cap 1 t-shirt (score:0.468711497559758)
# Recommended: Cap 1 scoop (score:0.4544521382134229)
# Recommended: Cap 1 graphic t-shirt (score:0.4336557190042913)
# Recommended: Cap 1 crew (score:0.4302834865649564)
# Recommended: Cap 1 graphic t-shirt (score:0.4164206473653204)
# Recommended: Cap 1 graphic crew (score:0.41612615842222556)
# Recommended: Cap 1 graphic tee (score:0.25606958436154287)
# Recommended: Cap 2 bottoms (score:0.2514473819614524)
#
#
#
#
# Recommending 10 products similar to Cap 1 boxer briefs with threshold 0.2...
# -------
# Recommended: Active boxer briefs (score:0.5283612680341314)
# Recommended: Active briefs (score:0.22221365425398973)
# Recommended: Active classic boxers (score:0.2203792147261746)
#
#
#
#
# Recommending 10 products similar to Cap 1 graphic t-shirt with threshold 0.2...
# -------
# Recommended: Cap 1 graphic t-shirt (score:0.6681227479230891)
# Recommended: Cap 1 graphic crew (score:0.6627265635417604)
# Recommended: Cap 1 t-shirt (score:0.6209270284663299)
# Recommended: Cap 1 crew (score:0.5607101445490794)
# Recommended: Cap 1 t-shirt (score:0.5374827505943757)
# Recommended: Cap 1 scoop (score:0.48360555672090855)
# Recommended: Cap 1 bottoms (score:0.4392251037745794)
# Recommended: Cap 1 bottoms (score:0.4336557190042913)
# Recommended: Cap 1 graphic tee (score:0.28464968248353706)
#
#
#
#
# Recommending 10 products similar to Cap 1 t-shirt with threshold 0.2...
# -------
# Recommended: Cap 1 graphic t-shirt (score:0.6209270284663299)
# Recommended: Cap 1 graphic crew (score:0.600356551465248)
# Recommended: Cap 1 crew (score:0.5911193687131717)
# Recommended: Cap 1 t-shirt (score:0.5766557156725726)
# Recommended: Cap 1 scoop (score:0.5034580391792773)
# Recommended: Cap 1 graphic t-shirt (score:0.49777414329925646)
# Recommended: Cap 1 bottoms (score:0.47531176310649514)
# Recommended: Cap 1 bottoms (score:0.468711497559758)
# Recommended: Cap 1 graphic tee (score:0.28484602863141495)
#
#
#
#
# Recommending 10 products similar to Cap 2 t-shirt with threshold 0.2...
# -------
# Recommended: Cap 2 crew (score:0.7049890803634628)
# Recommended: Cap 2 t-shirt (score:0.7041906217524192)
# Recommended: Cap 2 cap sleeve (score:0.6635362790007221)
# Recommended: Cap 2 zip neck (score:0.6225162259563579)
# Recommended: Cap 2 zip neck (score:0.5295225236280278)
# Recommended: Cap 2 v-neck (score:0.5094581638236435)
# Recommended: Cap 2 bottoms (score:0.41582263836147854)
# Recommended: Cap 2 bottoms (score:0.3846137053121345)
# Recommended: Cap 3 crew (score:0.2685095178845802)
# Recommended: Cap 3 crew (score:0.22979312127318086)
#
#
#
#
# Recommending 10 products similar to Cap 2 zip neck with threshold 0.2...
# -------
# Recommended: Cap 2 zip neck (score:0.6344950850896232)
# Recommended: Cap 2 t-shirt (score:0.6225162259563579)
# Recommended: Cap 2 t-shirt (score:0.5692208052197043)
# Recommended: Cap 2 crew (score:0.5672627008820263)
# Recommended: Cap 2 cap sleeve (score:0.566985087786813)
# Recommended: Cap 2 v-neck (score:0.47303861601300706)
# Recommended: Cap 2 bottoms (score:0.3858009796517637)
# Recommended: Cap 2 bottoms (score:0.3614905740829708)
# Recommended: Cap 3 zip neck (score:0.30885567349401766)
# Recommended: Cap 4 zip neck (score:0.25263073751227483)
#
#
#
#
# Recommending 10 products similar to Cap 3 zip neck with threshold 0.2...
# -------
# Recommended: Cap 3 crew (score:0.6843679481573038)
# Recommended: Cap 3 crew (score:0.6309802636575084)
# Recommended: Cap 3 bottoms (score:0.4991394361391152)
# Recommended: Cap 3 bottoms (score:0.4794057268584479)
# Recommended: Cap 2 zip neck (score:0.3089651968588025)
# Recommended: Cap 2 zip neck (score:0.30885567349401766)
# Recommended: Cap 4 zip neck (score:0.29039809196400707)
# Recommended: Cap 4 zip neck (score:0.25752532674611683)
# Recommended: Cap 2 crew (score:0.22613375444192743)
# Recommended: Cap 2 t-shirt (score:0.20299834085255983)
#
#
#
#
# Recommending 10 products similar to Cap 4 bottoms with threshold 0.2...
# -------
# Recommended: Cap 4 bottoms (score:0.6573821798739569)
# Recommended: Cap 4 zip neck (score:0.5308507649075463)
# Recommended: Cap 4 zip neck (score:0.49917597410078485)
# Recommended: Cap 3 bottoms (score:0.26279920332755136)
# Recommended: Cap 3 bottoms (score:0.2510756014800193)
# Recommended: Cap 3 crew (score:0.2158276399236214)
# Recommended: Cap 2 bottoms (score:0.20228525585435636)
#
#
#
#
# Recommending 10 products similar to City by the sea t-shirt with threshold 0.2...
# -------
# Recommended: Dragoons t-shirt (score:0.37875332095660125)
# Recommended: Flying fish 2 t-shirt (score:0.3677792235783415)
# Recommended: Mountain island t-shirt (score:0.33675481642591004)
# Recommended: Squid t-shirt (score:0.3326695216369357)
# Recommended: Live simply guitar t-shirt (score:0.3318941169039483)
# Recommended: La surfer maria t-shirt (score:0.33142118313046703)
# Recommended: '73 logo t-shirt (score:0.32960720857635634)
# Recommended: Organic logo t-shirt (score:0.3248326426816073)
# Recommended: Live simply bug t-shirt (score:0.323387217004477)
# Recommended: Future of the earth t-shirt (score:0.3212523400268479)
#
#
#
#
# Recommending 10 products similar to Compound cargo pants with threshold 0.2...
# -------
# Recommended: Compound cargo pants (score:0.9333114560598379)
# Recommended: Compound cargo pants (score:0.9325715856217309)
# Recommended: Compound cargo shorts (score:0.5092629518557479)
# Recommended: Custodian pants (score:0.23294815626924592)
# Recommended: Custodian pants (score:0.20822425945632167)
# Recommended: Custodian pants (score:0.20800170145610242)
#
#
#
#
# Recommending 10 products similar to Compound cargo pants with threshold 0.2...
# -------
# Recommended: Compound cargo pants (score:0.9405490620389073)
# Recommended: Compound cargo pants (score:0.9333114560598379)
# Recommended: Compound cargo shorts (score:0.5117925102595462)
# Recommended: Custodian pants (score:0.2302396857977833)
# Recommended: Custodian pants (score:0.2083204807436364)
# Recommended: Custodian pants (score:0.20798165884496014)
#
#
#
#
# Recommending 10 products similar to Continental shorts with threshold 0.2...
# -------
# Recommended: Continental pants (score:0.44851640238379126)
#
#
#
#
# Recommending 10 products similar to Cotton board shorts with threshold 0.2...
# -------
#
#
#
#
# Recommending 10 products similar to Crosstown with threshold 0.2...
# -------
# Recommended: Lightwire (score:0.3758332684571561)
# Recommended: Lightwire brief (score:0.32623116015092557)
# Recommended: Daily grind (score:0.27593132777573465)
# Recommended: Pocket pack (score:0.25627539209671224)
# Recommended: Single shot (score:0.2529056072214161)
# Recommended: Atom (score:0.20446199842679574)
# Recommended: Hip pack (score:0.20333055417406964)
#
#
#
#
# Recommending 10 products similar to Custodian pants with threshold 0.2...
# -------
# Recommended: Custodian pants (score:0.9032073991345075)
# Recommended: Custodian pants (score:0.9020484306816438)
# Recommended: All-wear cargo shorts (score:0.38377153738560726)
# Recommended: Delivery shorts (score:0.3214432423792207)
# Recommended: All-wear shorts (score:0.31556134422934085)
# Recommended: Shop pants (score:0.27582069347081833)
# Recommended: Duck pants (score:0.2713781940673174)
# Recommended: Shop pants (score:0.2598637705400414)
# Recommended: Shop pants (score:0.2597508298428583)
# Recommended: All-wear capris (score:0.2535569438030771)
#
#
#
#
# Recommending 10 products similar to Deep wading jkt with threshold 0.2...
# -------
# Recommended: Guidewater jkt (score:0.351617583584058)
# Recommended: Sst jkt (score:0.22654998552760272)
# Recommended: Rain shadow jkt (score:0.20178888433578007)
#
#
#
#
# Recommending 10 products similar to Delivery shorts with threshold 0.2...
# -------
# Recommended: Custodian pants (score:0.3236651729696741)
# Recommended: Custodian pants (score:0.3218202733696548)
# Recommended: Custodian pants (score:0.3214432423792207)
# Recommended: Thrift shorts (score:0.2842680874874073)
# Recommended: All-wear cargo shorts (score:0.28349723689192663)
# Recommended: All-wear shorts (score:0.2566286733846448)
# Recommended: Fezzman shirt (score:0.2397028832783174)
# Recommended: S/s island hopper shirt (score:0.21360431696984353)
# Recommended: L/s island hopper shirt (score:0.21307925982810272)
#
#
#
#
# Recommending 10 products similar to Down sweater vest with threshold 0.2...
# -------
# Recommended: Down sweater vest (score:0.8145929179255021)
# Recommended: Down sweater (score:0.5316112056796977)
# Recommended: Down sweater (score:0.453756475783063)
# Recommended: Micro puff vest (score:0.22345475575051205)
# Recommended: Micro puff vest (score:0.21429990332326798)
#
#
#
#
# Recommending 10 products similar to Dragoons t-shirt with threshold 0.2...
# -------
# Recommended: City by the sea t-shirt (score:0.37875332095660125)
# Recommended: La surfer maria t-shirt (score:0.3613339630219294)
# Recommended: Flying fish 2 t-shirt (score:0.360657733483138)
# Recommended: Live simply deer t-shirt (score:0.3451155286108002)
# Recommended: Live simply guitar t-shirt (score:0.3403888894638141)
# Recommended: Organic logo t-shirt (score:0.3335370611111286)
# Recommended: Mountain island t-shirt (score:0.33051956151354395)
# Recommended: Squid t-shirt (score:0.3304360043896634)
# Recommended: Fish frenzy t-shirt (score:0.32911161576557)
# Recommended: Trout head t-shirt (score:0.3251562642285503)
#
#
#
#
# Recommending 10 products similar to Duck pants with threshold 0.2...
# -------
# Recommended: Duck pants (score:0.9139073627612282)
# Recommended: Duck pants (score:0.9129682337046948)
# Recommended: Duck shorts (score:0.33733748601845526)
# Recommended: Custodian pants (score:0.2713781940673174)
# Recommended: Custodian pants (score:0.24146132925667188)
# Recommended: Custodian pants (score:0.24120636598984607)
#
#
#
#
# Recommending 10 products similar to Elias fz sweatshirt with threshold 0.2...
# -------
# Recommended: Elias sweatshirt (score:0.2782682084187074)
# Recommended: Cotton fleece hoody (score:0.26265607432431826)
#
#
#
#
# Recommending 10 products similar to Elias sweatshirt with threshold 0.2...
# -------
# Recommended: Elias fz sweatshirt (score:0.2782682084187074)
#
#
#
#
# Recommending 10 products similar to Fezzman shirt with threshold 0.2...
# -------
# Recommended: L/s island hopper shirt (score:0.32765574838476647)
# Recommended: S/s casitas shirt (score:0.3244178653528759)
# Recommended: S/s island hopper shirt (score:0.3237396464280903)
# Recommended: Thrift shorts (score:0.25852716910185375)
# Recommended: S/s puckerware shirt (score:0.25430111721100235)
# Recommended: Delivery shorts (score:0.2397028832783174)
#
#
#
#
# Recommending 10 products similar to Fish frenzy t-shirt with threshold 0.2...
# -------
# Recommended: Peregrine t-shirt (score:0.4110301626864297)
# Recommended: Tarpon t-shirt (score:0.34642515322961703)
# Recommended: Flying fish 2 t-shirt (score:0.3406388965655454)
# Recommended: Trout head t-shirt (score:0.33713822099541046)
# Recommended: Wind path t-shirt (score:0.3370361283516138)
# Recommended: Dragoons t-shirt (score:0.32911161576557)
# Recommended: Rockpile t-shirt (score:0.3275157181379355)
# Recommended: Butterfly logo t-shirt (score:0.3225248987652794)
# Recommended: Text logo t-shirt (score:0.32123901937678356)
# Recommended: Trampoli t-shirt (score:0.317372166450369)
#
#
#
#
# Recommending 10 products similar to Freewheeler with threshold 0.2...
# -------
# Recommended: Freewheeler max (score:0.6896990390184948)
# Recommended: Mlc wheelie (score:0.21279952106418493)
#
#
#
#
# Recommending 10 products similar to Gi ii pants with threshold 0.2...
# -------
# Recommended: Gi ii zip-off pants (score:0.4112578367291441)
# Recommended: Gi ii shorts (score:0.2831409571824499)
#
#
#
#
# Recommending 10 products similar to Gi ii shorts with threshold 0.2...
# -------
# Recommended: Gi ii zip-off pants (score:0.42051925596526707)
# Recommended: Gi ii pants (score:0.2831409571824499)
#
#
#
#
# Recommending 10 products similar to Girl's boardie capris with threshold 0.2...
# -------
# Recommended: Girl's boardie shorts (score:0.21219424742794057)
#
#
#
#
# Recommending 10 products similar to Girl's boardie shorts with threshold 0.2...
# -------
# Recommended: Boardie shorts (score:0.5966928925110463)
# Recommended: Girl's boardie capris (score:0.21219424742794057)
#
#
#
#
# Recommending 10 products similar to Girl's cotton tank dress with threshold 0.2...
# -------
#
#
#
#
# Recommending 10 products similar to Going big in b.c. poster with threshold 0.2...
# -------
# Recommended: Wyoming climbing poster (score:0.7216115816685751)
# Recommended: Wild steelhead, alaska poster (score:0.6836354384876732)
# Recommended: Sticks 'n stones morocco poster (score:0.6351296822709666)
# Recommended: Lead an examined life poster (score:0.6059523396930568)
# Recommended: Symmetry w16 poster (score:0.5937018934480126)
# Recommended: Flyfishing the athabasca poster (score:0.5795434474319086)
# Recommended: Traversing auguille d'entreves (score:0.5680388827752266)
#
#
#
#
# Recommending 10 products similar to Great divider with threshold 0.2...
# -------
# Recommended: Sub divider (score:0.6735109210642164)
#
#
#
#
# Recommending 10 products similar to Guidewater duffle with threshold 0.2...
# -------
# Recommended: Guidewater duffle (score:0.6895541163108605)
#
#
#
#
# Recommending 10 products similar to Guidewater jkt with threshold 0.2...
# -------
# Recommended: Sst jkt (score:0.36021511505695997)
# Recommended: Deep wading jkt (score:0.351617583584058)
#
#
#
#
# Recommending 10 products similar to Guidewater shorts with threshold 0.2...
# -------
# Recommended: Guidewater pants (score:0.7214291304557552)
#
#
#
#
# Recommending 10 products similar to Guidewater vest with threshold 0.2...
# -------
# Recommended: Riverwalker vest (score:0.41497496049964616)
#
#
#
#
# Recommending 10 products similar to Highwater pfd vest with threshold 0.2...
# -------
#
#
#
#
# Recommending 10 products similar to Hip chest pack with threshold 0.2...
# -------
# Recommended: Double haul (score:0.3569287428594805)
# Recommended: Pack vest (score:0.21107850865175828)
#
#
#
#
# Recommending 10 products similar to Iceberg t-shirt with threshold 0.2...
# -------
# Recommended: Rockpile t-shirt (score:0.43763220290290306)
# Recommended: Wind path t-shirt (score:0.3718769227916542)
# Recommended: Text logo t-shirt (score:0.3714181505799985)
# Recommended: Squid t-shirt (score:0.3516576070144948)
# Recommended: Peregrine t-shirt (score:0.34742596336980325)
# Recommended: Caribou north wind t-shirt (score:0.34454124375681183)
# Recommended: Tarpon t-shirt (score:0.33190986520799765)
# Recommended: Flying fish 2 t-shirt (score:0.331183152638741)
# Recommended: Trout head t-shirt (score:0.3310711756428408)
# Recommended: '73 logo t-shirt (score:0.33071464050933724)
#
#
#
#
# Recommending 10 products similar to Insulator pants with threshold 0.2...
# -------
# Recommended: Shelled insulator pants (score:0.210350330110114)
#
#
#
#
# Recommending 10 products similar to '73 logo t-shirt with threshold 0.2...
# -------
# Recommended: Flying fish t-shirt (score:0.9108243808208858)
# Recommended: Gpiw classic t-shirt (score:0.9053530683654106)
# Recommended: Live simply guitar t-shirt (score:0.8961878040125459)
# Recommended: Girl's live simply deer t-shirt (score:0.8100918892193385)
# Recommended: Girl's live simply seal t-shirt (score:0.8072652420751545)
# Recommended: Baby tag you're it t-shirt (score:0.2997591584796572)
# Recommended: '73 logo t-shirt (score:0.289891773637243)
# Recommended: Baby circus t-shirt (score:0.278964641082323)
# Recommended: Baby live simply deer t-shirt (score:0.24379764165875528)
# Recommended: Rockpile t-shirt (score:0.24066433308533253)
#
#
#
#
# Recommending 10 products similar to Borderless gi shorts with threshold 0.2...
# -------
# Recommended: Borderless shorts-7 in. (score:0.211977553456227)
# Recommended: Borderless shorts-11 in. (score:0.20850892691071193)
#
#
#
#
# Recommending 10 products similar to Cap 1 graphic tee with threshold 0.2...
# -------
# Recommended: Cap 1 crew (score:0.28973177473988854)
# Recommended: Cap 1 t-shirt (score:0.28598921277152983)
# Recommended: Cap 1 t-shirt (score:0.28484602863141495)
# Recommended: Cap 1 graphic t-shirt (score:0.28464968248353706)
# Recommended: Cap 1 graphic t-shirt (score:0.2813268812134916)
# Recommended: Cap 1 scoop (score:0.2743422186958016)
# Recommended: Cap 1 bottoms (score:0.2628362810609299)
# Recommended: Cap 1 graphic crew (score:0.2566889186685085)
# Recommended: Cap 1 bottoms (score:0.25606958436154287)
#
#
#
#
# Recommending 10 products similar to Cap 3 bottoms with threshold 0.2...
# -------
# Recommended: Cap 3 crew (score:0.37516959664142985)
# Recommended: Cap 3 bottoms (score:0.26188439723999063)
# Recommended: Cap 3 bottoms (score:0.25403203925738566)
# Recommended: Cap 3 crew (score:0.23942046516379803)
# Recommended: Cap 3 crew (score:0.21580738082163753)
#
#
#
#
# Recommending 10 products similar to El cap jkt with threshold 0.2...
# -------
# Recommended: El cap jkt (score:0.2412237392087456)
#
#
#
#
# Recommending 10 products similar to Flying fish t-shirt with threshold 0.2...
# -------
# Recommended: '73 logo t-shirt (score:0.9108243808208858)
# Recommended: Gpiw classic t-shirt (score:0.9015945446592044)
# Recommended: Live simply guitar t-shirt (score:0.892467329399611)
# Recommended: Girl's live simply deer t-shirt (score:0.8067288370839604)
# Recommended: Girl's live simply seal t-shirt (score:0.8039139246106722)
# Recommended: Flying fish 2 t-shirt (score:0.3091263553750941)
# Recommended: Baby tag you're it t-shirt (score:0.2985147247414113)
# Recommended: Baby circus t-shirt (score:0.27780653464480404)
# Recommended: Baby live simply deer t-shirt (score:0.24278552909437592)
# Recommended: Rockpile t-shirt (score:0.23966522827998513)
#
#
#
#
# Recommending 10 products similar to Gpiw classic t-shirt with threshold 0.2...
# -------
# Recommended: '73 logo t-shirt (score:0.9053530683654106)
# Recommended: Flying fish t-shirt (score:0.9015945446592044)
# Recommended: Live simply guitar t-shirt (score:0.8871062875585406)
# Recommended: Girl's live simply deer t-shirt (score:0.8018828254625432)
# Recommended: Girl's live simply seal t-shirt (score:0.799084822138812)
# Recommended: Baby tag you're it t-shirt (score:0.2967215499362435)
# Recommended: Baby circus t-shirt (score:0.27613775371928195)
# Recommended: Baby live simply deer t-shirt (score:0.24132711898007272)
# Recommended: Rockpile t-shirt (score:0.23822556177978596)
# Recommended: Baby live simply seal t-shirt (score:0.2272031880224954)
#
#
#
#
# Recommending 10 products similar to Live simply guitar t-shirt with threshold 0.2...
# -------
# Recommended: '73 logo t-shirt (score:0.8961878040125459)
# Recommended: Flying fish t-shirt (score:0.892467329399611)
# Recommended: Gpiw classic t-shirt (score:0.8871062875585406)
# Recommended: Girl's live simply deer t-shirt (score:0.8202636525774635)
# Recommended: Girl's live simply seal t-shirt (score:0.8174015131808209)
# Recommended: Baby tag you're it t-shirt (score:0.29371771470401997)
# Recommended: Live simply guitar t-shirt (score:0.2800300594490298)
# Recommended: Baby live simply deer t-shirt (score:0.27576879346100297)
# Recommended: Baby circus t-shirt (score:0.27334229678753125)
# Recommended: Baby live simply seal t-shirt (score:0.25962912620951917)
#
#
#
#
# Recommending 10 products similar to Synch marsupial with threshold 0.2...
# -------
# Recommended: Baby synch vest (score:0.3594861811546657)
# Recommended: Baby synch cardigan (score:0.34854275730174955)
# Recommended: Synch vest (score:0.2699528721465622)
# Recommended: Synch vest (score:0.261138002095995)
#
#
#
#
# Recommending 10 products similar to Torrentshell jkt with threshold 0.2...
# -------
# Recommended: Rain shadow jkt (score:0.23885819327432883)
# Recommended: Rain shadow jkt (score:0.2363945317399587)
# Recommended: Rain shadow pants (score:0.22025132122716704)
# Recommended: Rain shadow pants (score:0.21993842689385612)
# Recommended: Torrentshell pants (score:0.21925039681865538)
# Recommended: Torrentshell pants (score:0.21612667322608442)
# Recommended: Torrentshell pants (score:0.21612259422748661)
# Recommended: Rain shadow trench coat (score:0.20927125622854106)
# Recommended: Torrentshell jkt (score:0.20142122220791234)
#
#
#
#
# Recommending 10 products similar to La surfer maria t-shirt with threshold 0.2...
# -------
# Recommended: Organic logo t-shirt (score:0.3692080722309289)
# Recommended: Mountain island t-shirt (score:0.366919468434053)
# Recommended: Dragoons t-shirt (score:0.3613339630219294)
# Recommended: Flying fish 2 t-shirt (score:0.3341259494862827)
# Recommended: City by the sea t-shirt (score:0.33142118313046703)
# Recommended: Live simply deer t-shirt (score:0.3275631859537021)
# Recommended: Hills t-shirt (score:0.32472262953315917)
# Recommended: Squid t-shirt (score:0.31956458792100517)
# Recommended: Live simply guitar t-shirt (score:0.31948264709288304)
# Recommended: The more you know t-shirt (score:0.31797491432354635)
#
#
#
#
# Recommending 10 products similar to Lead an examined life poster with threshold 0.2...
# -------
# Recommended: Symmetry w16 poster (score:0.761739485413713)
# Recommended: Wyoming climbing poster (score:0.6411979399045494)
# Recommended: Flyfishing the athabasca poster (score:0.6294065125011532)
# Recommended: Traversing auguille d'entreves (score:0.6171464361249788)
# Recommended: Wild steelhead, alaska poster (score:0.6074537132434257)
# Recommended: Going big in b.c. poster (score:0.6059523396930568)
# Recommended: Sticks 'n stones morocco poster (score:0.5647187318326301)
#
#
#
#
# Recommending 10 products similar to Light and variable surf trunks with threshold 0.2...
# -------
# Recommended: Paddler board shorts (score:0.20669606455013173)
#
#
#
#
# Recommending 10 products similar to Live simply bug t-shirt with threshold 0.2...
# -------
# Recommended: Live simply deer t-shirt (score:0.35786466121935506)
# Recommended: Live simply guitar t-shirt (score:0.3453461123976978)
# Recommended: Baby live simply deer t-shirt (score:0.3301615527444832)
# Recommended: Flying fish 2 t-shirt (score:0.3252715506688463)
# Recommended: City by the sea t-shirt (score:0.323387217004477)
# Recommended: Dragoons t-shirt (score:0.3135043661007454)
# Recommended: Squid t-shirt (score:0.31275549160836164)
# Recommended: Baby live simply seal t-shirt (score:0.31083849035714084)
# Recommended: Live simply deer t-shirt (score:0.3094151453194881)
# Recommended: The more you know t-shirt (score:0.30043839405271816)
#
#
#
#
# Recommending 10 products similar to Live simply deer t-shirt with threshold 0.2...
# -------
# Recommended: Live simply deer t-shirt (score:0.8572941375329496)
# Recommended: Baby live simply deer t-shirt (score:0.5116094608869235)
# Recommended: The more you know t-shirt (score:0.40717734008557627)
# Recommended: Flying fish 2 t-shirt (score:0.40033658215464735)
# Recommended: Live simply guitar t-shirt (score:0.39437076691402406)
# Recommended: Organic logo t-shirt (score:0.38424201307148187)
# Recommended: Live simply bug t-shirt (score:0.35786466121935506)
# Recommended: Peregrine t-shirt (score:0.35551892991872336)
# Recommended: Live simply pelican t-shirt (score:0.35239148100919016)
# Recommended: Dragoons t-shirt (score:0.3451155286108002)
#
#
#
#
# Recommending 10 products similar to Live simply guitar t-shirt with threshold 0.2...
# -------
# Recommended: Live simply guitar t-shirt (score:0.8132167761824246)
# Recommended: Live simply deer t-shirt (score:0.39437076691402406)
# Recommended: Flying fish 2 t-shirt (score:0.3626377950999974)
# Recommended: Trout silhouette t-shirt (score:0.3606039591845194)
# Recommended: Live simply bug t-shirt (score:0.3453461123976978)
# Recommended: The more you know t-shirt (score:0.3444222086261028)
# Recommended: Live simply deer t-shirt (score:0.3419831469268337)
# Recommended: Baby live simply deer t-shirt (score:0.3411362565465133)
# Recommended: Dragoons t-shirt (score:0.3403888894638141)
# Recommended: Yosemite essence t-shirt (score:0.33986279148477844)
#
#
#
#
# Recommending 10 products similar to Logo hat with threshold 0.2...
# -------
#
#
#
#
# Recommending 10 products similar to L/s hooded rashguard with threshold 0.2...
# -------
# Recommended: L/s rashguard (score:0.7384779509677897)
# Recommended: S/s rashguard (score:0.7173507095210137)
# Recommended: S/s rashguard (score:0.4563928739536496)
# Recommended: L/s rashguard (score:0.45250619325621505)
# Recommended: Rashguard (score:0.2770462291957236)
#
#
#
#
# Recommending 10 products similar to L/s island hopper shirt with threshold 0.2...
# -------
# Recommended: S/s island hopper shirt (score:0.8013463830281642)
# Recommended: Fezzman shirt (score:0.32765574838476647)
# Recommended: S/s puckerware shirt (score:0.22700983120656165)
# Recommended: Delivery shorts (score:0.21307925982810272)
# Recommended: Thrift shorts (score:0.2128725179357925)
#
#
#
#
# Recommending 10 products similar to L/s rashguard with threshold 0.2...
# -------
# Recommended: S/s rashguard (score:0.9533710538575099)
# Recommended: L/s hooded rashguard (score:0.7384779509677897)
# Recommended: S/s rashguard (score:0.4848634690827261)
# Recommended: L/s rashguard (score:0.4819204862108103)
# Recommended: Rashguard (score:0.30919653962585114)
#
#
#
#
# Recommending 10 products similar to L/s steersman shirt with threshold 0.2...
# -------
#
#
#
#
# Recommending 10 products similar to Lw endurance ankle socks with threshold 0.2...
# -------
# Recommended: Lw endurance quarter socks (score:0.62092158608737)
# Recommended: Ultra lw endurance ped socks (score:0.42048543843375236)
# Recommended: Mw hiking crew socks (score:0.32279440482158495)
# Recommended: Lw hiking crew socks (score:0.2851687798526627)
# Recommended: Ulw hiking crew socks (score:0.24613399760856947)
# Recommended: Ultra hw mountaineering socks (score:0.2372024528429845)
# Recommended: Lw hiking crew liner socks (score:0.20172023548174065)
#
#
#
#
# Recommending 10 products similar to Lw endurance quarter socks with threshold 0.2...
# -------
# Recommended: Lw endurance ankle socks (score:0.62092158608737)
# Recommended: Ultra lw endurance ped socks (score:0.4476829151008896)
# Recommended: Mw hiking crew socks (score:0.3370442153185462)
# Recommended: Lw hiking crew socks (score:0.3063453867966967)
# Recommended: Ulw hiking crew socks (score:0.2716809725251542)
# Recommended: Ultra hw mountaineering socks (score:0.24832708499376266)
# Recommended: Lw hiking crew liner socks (score:0.20014530158758598)
#
#
#
#
# Recommending 10 products similar to Lw hiking crew socks with threshold 0.2...
# -------
# Recommended: Ulw hiking crew socks (score:0.4185656885112028)
# Recommended: Mw hiking crew socks (score:0.38025176498815444)
# Recommended: Lw endurance quarter socks (score:0.3063453867966967)
# Recommended: Lw endurance ankle socks (score:0.2851687798526627)
# Recommended: Ultra hw mountaineering socks (score:0.2787377792845178)
# Recommended: Ultra lw endurance ped socks (score:0.26014444171971784)
#
#
#
#
# Recommending 10 products similar to Lw r4 jkt with threshold 0.2...
# -------
# Recommended: Lw r4 jkt (score:0.9252465651645175)
# Recommended: R2 jkt (score:0.20784319901787576)
#
#
#
#
# Recommending 10 products similar to Lw travel duffel with threshold 0.2...
# -------
# Recommended: Lw travel courier (score:0.29759184888828494)
# Recommended: Lw travel pack (score:0.29077268952909674)
# Recommended: Lw travel tote (score:0.2775137067860127)
#
#
#
#
# Recommending 10 products similar to Lw travel pack with threshold 0.2...
# -------
# Recommended: Lw travel tote (score:0.38224666604242113)
# Recommended: Lw travel courier (score:0.3382844936923809)
# Recommended: Lw travel duffel (score:0.29077268952909674)
#
#
#
#
# Recommending 10 products similar to M10 jkt with threshold 0.2...
# -------
# Recommended: M10 jkt (score:0.9322179611179893)
# Recommended: Torrentshell jkt (score:0.34688221952680814)
# Recommended: Torrentshell jkt (score:0.3397129099167037)
# Recommended: Rain shadow jkt (score:0.30261654133652555)
# Recommended: M10 pants (score:0.29998237743576045)
# Recommended: Rain shadow jkt (score:0.2971905771709666)
# Recommended: Stretch ascent jkt (score:0.2173519586014489)
# Recommended: Stretch ascent jkt (score:0.21354120043850303)
# Recommended: Torrentshell pants (score:0.21018270345502577)
# Recommended: Torrentshell pants (score:0.2086578818224267)
#
#
#
#
# Recommending 10 products similar to M10 pants with threshold 0.2...
# -------
# Recommended: M10 jkt (score:0.29998237743576045)
# Recommended: M10 jkt (score:0.2941703417504911)
# Recommended: Torrentshell pants (score:0.21737516739821366)
# Recommended: Torrentshell pants (score:0.21680683100007572)
# Recommended: Rain shadow pants (score:0.21193312532208008)
# Recommended: Rain shadow pants (score:0.21163204801827673)
#
#
#
#
# Recommending 10 products similar to Merino 1 crew with threshold 0.2...
# -------
# Recommended: Merino 1 t-shirt (score:0.6490161598583352)
# Recommended: Merino 1 crew (score:0.6385540623104611)
# Recommended: Merino 1 graphic t-shirt (score:0.6168376730361484)
# Recommended: Merino 1 t-shirt (score:0.6142503723031474)
# Recommended: Merino 1 tank (score:0.5795538801791587)
# Recommended: Merino 2 crew (score:0.5312127545245405)
# Recommended: Merino 2 crew (score:0.45763921109300076)
# Recommended: Merino 2 t-shirt (score:0.4576097778373206)
# Recommended: Merino 2 bottoms (score:0.4430415905801494)
# Recommended: Merino 2 polo (score:0.44173832718983536)
#
#
#
#
# Recommending 10 products similar to Merino 1 t-shirt with threshold 0.2...
# -------
# Recommended: Merino 1 crew (score:0.7559689146017282)
# Recommended: Merino 1 t-shirt (score:0.7005765371335265)
# Recommended: Merino 1 graphic t-shirt (score:0.6983391545795753)
# Recommended: Merino 1 tank (score:0.6738398804186708)
# Recommended: Merino 1 crew (score:0.6490161598583352)
# Recommended: Merino 2 crew (score:0.4796474598336993)
# Recommended: Merino 2 t-shirt (score:0.469709488093083)
# Recommended: Merino 2 bottoms (score:0.4674086609194774)
# Recommended: Merino 2 bottoms (score:0.4513457938088641)
# Recommended: Merino 2 t-shirt (score:0.44776398600025025)
#
#
#
#
# Recommending 10 products similar to Merino 2 polo with threshold 0.2...
# -------
# Recommended: Merino 2 t-shirt (score:0.6627218930438882)
# Recommended: Merino 2 bottoms (score:0.6323953372141048)
# Recommended: Merino 2 bottoms (score:0.6121277706073257)
# Recommended: Merino 2 crew (score:0.6018782098696157)
# Recommended: Merino 2 crew (score:0.5683494594687434)
# Recommended: Merino 2 t-shirt (score:0.5474223305741465)
# Recommended: Merino 2 dress (score:0.5266566579166622)
# Recommended: Merino 1 t-shirt (score:0.4420357576662773)
# Recommended: Merino 1 crew (score:0.44173832718983536)
# Recommended: Merino 1 crew (score:0.44078461163020627)
#
#
#
#
# Recommending 10 products similar to Merino 2 t-shirt with threshold 0.2...
# -------
# Recommended: Merino 2 crew (score:0.7387583673473276)
# Recommended: Merino 2 polo (score:0.6627218930438882)
# Recommended: Merino 2 bottoms (score:0.6433303120933099)
# Recommended: Merino 2 bottoms (score:0.6354414878769344)
# Recommended: Merino 2 t-shirt (score:0.6213454076383335)
# Recommended: Merino 2 crew (score:0.6097511363106206)
# Recommended: Merino 2 dress (score:0.5396530354364161)
# Recommended: Merino 1 t-shirt (score:0.469709488093083)
# Recommended: Merino 1 crew (score:0.4603842313913137)
# Recommended: Merino 1 t-shirt (score:0.458477566949799)
#
#
#
#
# Recommending 10 products similar to Migration hemp shirt with threshold 0.2...
# -------
#
#
#
#
# Recommending 10 products similar to Minimalist board shorts-19 in. with threshold 0.2...
# -------
# Recommended: Twenty-three's board shorts (score:0.4692885531992873)
# Recommended: Wavefarer board shorts-21 in. (score:0.4577745796493879)
# Recommended: Paddler board shorts (score:0.27192038148392694)
#
#
#
#
# Recommending 10 products similar to Minimass with threshold 0.2...
# -------
# Recommended: Critical mass (score:0.22835311059702382)
# Recommended: Half mass (score:0.2234399716864217)
#
#
#
#
# Recommending 10 products similar to Mlc wheelie with threshold 0.2...
# -------
# Recommended: Mlc (score:0.2580151206672012)
# Recommended: Freewheeler (score:0.21279952106418493)
#
#
#
#
# Recommending 10 products similar to Mountain island t-shirt with threshold 0.2...
# -------
# Recommended: Organic logo t-shirt (score:0.38581460869003753)
# Recommended: La surfer maria t-shirt (score:0.366919468434053)
# Recommended: Flying fish 2 t-shirt (score:0.3528309437678981)
# Recommended: Rockpile t-shirt (score:0.34164728307580206)
# Recommended: Hills t-shirt (score:0.33734810281894617)
# Recommended: City by the sea t-shirt (score:0.33675481642591004)
# Recommended: The more you know t-shirt (score:0.3365816311519974)
# Recommended: Vintage logo pkt t-shirt (score:0.334791594254154)
# Recommended: Dragoons t-shirt (score:0.33051956151354395)
# Recommended: '73 logo t-shirt (score:0.32257501853140713)
#
#
#
#
# Recommending 10 products similar to Nine trails jkt with threshold 0.2...
# -------
# Recommended: Nine trails jkt (score:0.8664478880889563)
# Recommended: Nine trails vest (score:0.5450655230186492)
# Recommended: Nine trails vest (score:0.5415288245927994)
# Recommended: Houdini full-zip jkt (score:0.20227380283399365)
#
#
#
#
# Recommending 10 products similar to Nine trails shorts with threshold 0.2...
# -------
# Recommended: Nine trails shorts (score:0.7427820064014974)
# Recommended: Ultra shorts (score:0.3349172897492588)
# Recommended: Long haul runners (score:0.2945303055955865)
# Recommended: Multi use shorts (score:0.22150214184484351)
# Recommended: Nine trails vest (score:0.2150055770900287)
# Recommended: Nine trails vest (score:0.2123726126031233)
# Recommended: Multi use skirt (score:0.20167360458460012)
#
#
#
#
# Recommending 10 products similar to Organic logo t-shirt with threshold 0.2...
# -------
# Recommended: Mountain island t-shirt (score:0.38581460869003753)
# Recommended: Live simply deer t-shirt (score:0.38424201307148187)
# Recommended: Flying fish 2 t-shirt (score:0.3762839603261779)
# Recommended: Vintage logo pkt t-shirt (score:0.3756107019376241)
# Recommended: La surfer maria t-shirt (score:0.3692080722309289)
# Recommended: Text logo t-shirt (score:0.360373102798951)
# Recommended: Hills t-shirt (score:0.3599658787228378)
# Recommended: '73 logo t-shirt (score:0.3460870591948347)
# Recommended: The more you know t-shirt (score:0.34595337331874415)
# Recommended: Squid t-shirt (score:0.3455959837713632)
#
#
#
#
# Recommending 10 products similar to O web belt with threshold 0.2...
# -------
# Recommended: Tech web belt (score:0.26222312788655144)
# Recommended: Travel belt (score:0.22000065279040146)
#
#
#
#
# Recommending 10 products similar to Paddler board shorts with threshold 0.2...
# -------
# Recommended: Minimalist board shorts-19 in. (score:0.27192038148392694)
# Recommended: Wavefarer board shorts-21 in. (score:0.22439507803604267)
# Recommended: Twenty-three's board shorts (score:0.21771388622185206)
# Recommended: Light and variable surf trunks (score:0.20669606455013173)
#
#
#
#
# Recommending 10 products similar to Pataloha shirt with threshold 0.2...
# -------
#
#
#
#
# Recommending 10 products similar to Planer t-shirt with threshold 0.2...
# -------
# Recommended: Trout head t-shirt (score:0.35185273559894104)
# Recommended: Yosemite essence t-shirt (score:0.3262212540783407)
# Recommended: Fitz roy study t-shirt (score:0.3127972847815611)
# Recommended: Vintage logo pkt t-shirt (score:0.3123778723881895)
# Recommended: Live simply deer t-shirt (score:0.30701111262010977)
# Recommended: Peregrine t-shirt (score:0.3057320506651756)
# Recommended: Flying fish 2 t-shirt (score:0.3045085304997968)
# Recommended: Rockpile t-shirt (score:0.30214945206238536)
# Recommended: Live simply guitar t-shirt (score:0.29619723598903114)
# Recommended: Permit silhouette t-shirt (score:0.29567840162684594)
#
#
#
#
# Recommending 10 products similar to Platform t-shirt with threshold 0.2...
# -------
# Recommended: Flying fish 2 t-shirt (score:0.24967385737177092)
# Recommended: Rockpile t-shirt (score:0.23837987463403826)
# Recommended: Squid t-shirt (score:0.22796748732452488)
# Recommended: Live simply deer t-shirt (score:0.22113606813129436)
# Recommended: Iceberg t-shirt (score:0.21829440984861015)
# Recommended: Live simply guitar t-shirt (score:0.21805700295484423)
# Recommended: The more you know t-shirt (score:0.21546810958186086)
# Recommended: Future of the earth t-shirt (score:0.21141368648331113)
# Recommended: Organic logo t-shirt (score:0.207582501122228)
# Recommended: Dragoons t-shirt (score:0.20652677422409654)
#
#
#
#
# Recommending 10 products similar to Pocket pack with threshold 0.2...
# -------
# Recommended: Lightwire (score:0.30839636264047404)
# Recommended: Hip pack (score:0.27359141874773923)
# Recommended: Crosstown (score:0.25627539209671224)
# Recommended: Atom (score:0.2549889349464077)
# Recommended: Lightwire brief (score:0.22269828215790818)
# Recommended: Single shot (score:0.22238439030772)
# Recommended: Daily grind (score:0.21275384608311596)
#
#
#
#
# Recommending 10 products similar to R1 hoody with threshold 0.2...
# -------
# Recommended: R1 full-zip jkt (score:0.34491456662973763)
# Recommended: R1 full-zip jkt (score:0.34246074628308937)
# Recommended: R1 p/o (score:0.24431119662582518)
# Recommended: R1 p/o (score:0.23581682953881997)
#
#
#
#
# Recommending 10 products similar to R1 p/o with threshold 0.2...
# -------
# Recommended: R1 p/o (score:0.6950899841063929)
# Recommended: R1 full-zip jkt (score:0.31636612420435284)
# Recommended: R1 full-zip jkt (score:0.3137306650307271)
# Recommended: R1 hoody (score:0.23581682953881997)
#
#
#
#
# Recommending 10 products similar to Rain shadow pants with threshold 0.2...
# -------
# Recommended: Rain shadow pants (score:0.9862089082808883)
# Recommended: Rain shadow jkt (score:0.47430720650861136)
# Recommended: Rain shadow jkt (score:0.46083669047110587)
# Recommended: Rain shadow trench coat (score:0.2956673469784762)
# Recommended: Torrentshell pants (score:0.23452242288610708)
# Recommended: Torrentshell pants (score:0.23390925427673465)
# Recommended: Torrentshell jkt (score:0.22025132122716704)
# Recommended: M10 pants (score:0.21193312532208008)
#
#
#
#
# Recommending 10 products similar to Reg fit organic ctn jeans-long with threshold 0.2...
# -------
# Recommended: Reg fit organic ctn jeans-reg (score:0.9534878451758879)
# Recommended: Reg fit organic ctn jeans-short (score:0.9522246792960248)
# Recommended: Relax fit organic ctn jeans-long (score:0.5228366582772305)
# Recommended: Relax fit organic ctn jeans-reg (score:0.4936927013110193)
# Recommended: Relax fit organic ctn jeans-shor (score:0.48801052800274014)
# Recommended: Shop pants (score:0.2487835174466656)
# Recommended: Shop pants (score:0.23946612142047038)
# Recommended: Shop pants (score:0.23807227344549528)
#
#
#
#
# Recommending 10 products similar to Reg fit organic ctn jeans-reg with threshold 0.2...
# -------
# Recommended: Reg fit organic ctn jeans-short (score:0.9536045210725154)
# Recommended: Reg fit organic ctn jeans-long (score:0.9534878451758879)
# Recommended: Relax fit organic ctn jeans-reg (score:0.5218538039979264)
# Recommended: Relax fit organic ctn jeans-long (score:0.4855802373950399)
# Recommended: Relax fit organic ctn jeans-shor (score:0.4848888488912978)
# Recommended: Shop pants (score:0.2479546098624955)
# Recommended: Shop pants (score:0.23792668309375425)
# Recommended: Shop pants (score:0.23754415449038577)
#
#
#
#
# Recommending 10 products similar to Relax fit organic ctn jeans-shor with threshold 0.2...
# -------
# Recommended: Relax fit organic ctn jeans-reg (score:0.8908101955877072)
# Recommended: Relax fit organic ctn jeans-long (score:0.8866113828050041)
# Recommended: Reg fit organic ctn jeans-short (score:0.5076682598655954)
# Recommended: Reg fit organic ctn jeans-long (score:0.48801052800274014)
# Recommended: Reg fit organic ctn jeans-reg (score:0.4848888488912978)
#
#
#
#
# Recommending 10 products similar to Remat with threshold 0.2...
# -------
#
#
#
#
# Recommending 10 products similar to Retro grade pants with threshold 0.2...
# -------
# Recommended: Retro grade shorts (score:0.4136659568876139)
#
#
#
#
# Recommending 10 products similar to Riverwalker with threshold 0.2...
# -------
# Recommended: Riverwalker (score:0.9010967838251541)
# Recommended: Riverwalker (score:0.8828362580958504)
# Recommended: Marlwalker (score:0.5563240857708183)
# Recommended: Surf sneaker (score:0.24108109955290952)
#
#
#
#
# Recommending 10 products similar to Riverwalker with threshold 0.2...
# -------
# Recommended: Riverwalker (score:0.9010967838251541)
# Recommended: Riverwalker (score:0.8864260498971578)
# Recommended: Marlwalker (score:0.5627754776157888)
# Recommended: Surf sneaker (score:0.24069597724021177)
#
#
#
#
# Recommending 10 products similar to Rock guide shorts with threshold 0.2...
# -------
# Recommended: Rock guide pants (score:0.41305276903677945)
# Recommended: Rock guide shorts (score:0.35709297306079885)
# Recommended: Rock guide pants (score:0.29392053569469084)
#
#
#
#
# Recommending 10 products similar to Rockpile t-shirt with threshold 0.2...
# -------
# Recommended: Iceberg t-shirt (score:0.43763220290290306)
# Recommended: Flying fish 2 t-shirt (score:0.4014908688123496)
# Recommended: Text logo t-shirt (score:0.39237490240097544)
# Recommended: '73 logo t-shirt (score:0.3899339169097087)
# Recommended: Owlin around t-shirt (score:0.3878510454591486)
# Recommended: Tarpon t-shirt (score:0.36250317264579957)
# Recommended: Squid t-shirt (score:0.35998000203271363)
# Recommended: Trout head t-shirt (score:0.3565993122050981)
# Recommended: Peregrine t-shirt (score:0.3541837005318376)
# Recommended: Ditch the car-ride t-shirt (score:0.3534409816156972)
# Recommending 10 products similar to Runshade top with threshold 0.2...
# -------
# Recommended: L/s runshade top (score:0.6118589217273248)
# Recommended: Runshade t-shirt (score:0.5386214969873796)
# Recommended: Runshade t-shirt (score:0.5299142171988567)
# Recommended: L/s runshade top (score:0.476473219459205)
#
#
#
#
# Recommending 10 products similar to Shop pants with threshold 0.2...
# -------
# Recommended: Shop pants (score:0.908753317300124)
# Recommended: Shop pants (score:0.9085259342535041)
# Recommended: Custodian pants (score:0.273793740065032)
# Recommended: Custodian pants (score:0.2597508298428583)
# Recommended: Custodian pants (score:0.25939696332174766)
# Recommended: Reg fit organic ctn jeans-reg (score:0.2479546098624955)
# Recommended: Reg fit organic ctn jeans-long (score:0.23946612142047038)
# Recommended: Reg fit organic ctn jeans-short (score:0.23905244939639902)
#
#
#
#
# Recommending 10 products similar to Shop pants with threshold 0.2...
# -------
# Recommended: Shop pants (score:0.908753317300124)
# Recommended: Shop pants (score:0.9087343193828904)
# Recommended: Custodian pants (score:0.2743076274871514)
# Recommended: Custodian pants (score:0.2598637705400414)
# Recommended: Custodian pants (score:0.2597948688796085)
# Recommended: Reg fit organic ctn jeans-short (score:0.24705744289907158)
# Recommended: Reg fit organic ctn jeans-long (score:0.23807227344549528)
# Recommended: Reg fit organic ctn jeans-reg (score:0.23754415449038577)
#
#
#
#
# Recommending 10 products similar to Simple guide jkt with threshold 0.2...
# -------
# Recommended: Simple guide jkt (score:0.9280413287811625)
# Recommended: Simple guide pants (score:0.2096970825989209)
#
#
#
#
# Recommending 10 products similar to Soaring jkt with threshold 0.2...
# -------
#
#
#
#
# Recommending 10 products similar to Sonar so no t-shirt with threshold 0.2...
# -------
# Recommended: Flying fish 2 t-shirt (score:0.2403426149288256)
# Recommended: Live simply deer t-shirt (score:0.23383400062112827)
# Recommended: Live simply guitar t-shirt (score:0.2307562591500809)
# Recommended: Squid t-shirt (score:0.22530316796778024)
# Recommended: World according to bikers t-shir (score:0.2220643516848119)
# Recommended: Rockpile t-shirt (score:0.2173584136239111)
# Recommended: The more you know t-shirt (score:0.2159713667345241)
# Recommended: Dragoons t-shirt (score:0.21458123051449957)
# Recommended: Organic logo t-shirt (score:0.21347196101602606)
# Recommended: City by the sea t-shirt (score:0.20873165109905492)
#
#
#
#
# Recommending 10 products similar to Special edition pataloha shirt with threshold 0.2...
# -------
#
#
#
#
# ...
# Recommended: Baggies shorts (score:0.27220059469253793)
# Recommended: Baby sun bucket hat (score:0.2166252228693151)
# Recommended: Baggies shorts (score:0.20774623732279854)
#
#
#
#
# Recommending 10 products similar to Baby circus t-shirt with threshold 0.2...
# -------
# Recommended: Baby live simply deer t-shirt (score:0.441860443463269)
# Recommended: Baby live simply seal t-shirt (score:0.4160000825442999)
# Recommended: Baby tag you're it t-shirt (score:0.3626853485830545)
# Recommended: Text logo t-shirt (score:0.33878293202768917)
# Recommended: Rockpile t-shirt (score:0.3260610686601291)
# Recommended: Bouquet t-shirt (score:0.3199630209813255)
# Recommended: '73 logo t-shirt (score:0.31932862324477856)
# Recommended: Squid t-shirt (score:0.3144389508067711)
# Recommended: City by the sea t-shirt (score:0.31119840901096923)
# Recommended: Flying fish 2 t-shirt (score:0.30512957549795044)
#
#
#
#
# Recommending 10 products similar to Guidewater waders with threshold 0.2...
# -------
# Recommended: Guidewater waders (score:0.9789276393206149)
# Recommended: Watermaster waders (score:0.6453015178828628)
# Recommended: Watermaster waders (score:0.6436700211917176)
# Recommended: Watermaster waders (score:0.6436291155990738)
# Recommended: Watermaster waders (score:0.6434050194063116)
# Recommended: Watermaster hip highs (score:0.4127584882598938)
#
#
#
#
# Recommending 10 products similar to Baby duality jkt with threshold 0.2...
# -------
# Recommended: Duality jkt (score:0.4884687961678689)
# Recommending 10 products similar to Baby live simply deer t-shirt with threshold 0.2...
# -------
# Recommended: Baby live simply seal t-shirt (score:0.7371334886173992)
# Recommended: Live simply deer t-shirt (score:0.5116094608869235)
# Recommended: Live simply deer t-shirt (score:0.4652068666866127)
# Recommended: Baby circus t-shirt (score:0.441860443463269)
# Recommended: Baby tag you're it t-shirt (score:0.3827597256511779)
# Recommended: Girl's live simply deer t-shirt (score:0.3640280930374177)
# Recommended: Live simply guitar t-shirt (score:0.3411362565465133)
# Recommended: Live simply bug t-shirt (score:0.3301615527444832)
# Recommended: Rockpile t-shirt (score:0.32526708528728754)
# Recommended: Flying fish 2 t-shirt (score:0.31336151058210865)
#
#
#
#
# Recommending 10 products similar to Baby live simply seal t-shirt with threshold 0.2...
# -------
# Recommended: Baby live simply deer t-shirt (score:0.7371334886173992)
# Recommended: Baby circus t-shirt (score:0.4160000825442999)
# Recommended: Baby tag you're it t-shirt (score:0.360358298238932)
# Recommended: Girl's live simply seal t-shirt (score:0.3506884264351039)
# Recommended: Live simply deer t-shirt (score:0.34386217035265476)
# Recommended: Live simply guitar t-shirt (score:0.31660636929501607)
# Recommended: Live simply deer t-shirt (score:0.31151015472757065)
# Recommended: Live simply bug t-shirt (score:0.31083849035714084)
# Recommended: Flying fish 2 t-shirt (score:0.30696693161601496)
# Recommended: Rockpile t-shirt (score:0.30623047690781485)
#
#
#
#
# Recommending 10 products similar to Double haul with threshold 0.2...
# -------
# Recommended: Hip chest pack (score:0.3569287428594805)
# Recommended: Pack vest (score:0.20910237512124719)
#
#
#
#
# Recommending 10 products similar to Down sweater with threshold 0.2...
# -------
# Recommended: Down sweater (score:0.8350425162001291)
# Recommended: Down sweater vest (score:0.5316112056796977)
# Recommended: Down sweater vest (score:0.4909378664939874)
# Recommended: Micro puff vest (score:0.22189823295207967)
# Recommended: Micro puff vest (score:0.21707835418527455)
#
#
#
#
# Recommending 10 products similar to Baby synch cardigan with threshold 0.2...
# -------
# Recommended: Synch marsupial (score:0.34854275730174955)
# Recommended: Baby synch vest (score:0.304418504302158)
#
#
#
#
# Recommending 10 products similar to Baby synch vest with threshold 0.2...
# -------
# Recommended: Synch marsupial (score:0.3594861811546657)
# Recommended: Baby synch cardigan (score:0.304418504302158)
# Recommended: Synch vest (score:0.24569881904652008)
# Recommended: Synch vest (score:0.21658021440047287)
#
#
#
#
# Recommending 10 products similar to Baby tag you're it t-shirt with threshold 0.2...
# -------
# Recommended: Baby live simply deer t-shirt (score:0.3827597256511779)
# Recommended: Baby circus t-shirt (score:0.3626853485830545)
# Recommended: Baby live simply seal t-shirt (score:0.360358298238932)
# Recommended: Iceberg t-shirt (score:0.3105779905663643)
# Recommended: '73 logo t-shirt (score:0.2997591584796572)
# Recommended: Flying fish t-shirt (score:0.2985147247414113)
# Recommended: Gpiw classic t-shirt (score:0.2967215499362435)
# Recommended: Squid t-shirt (score:0.29447355050022384)
# Recommended: Rockpile t-shirt (score:0.29405241503171414)
# Recommended: Live simply guitar t-shirt (score:0.29371771470401997)
#
#
#
#
# Recommending 10 products similar to L/s runshade top with threshold 0.2...
# -------
# Recommended: Runshade top (score:0.6118589217273248)
# Recommended: Runshade t-shirt (score:0.4890563329811598)
# Recommended: Runshade t-shirt (score:0.4651707389136935)
# Recommended: L/s runshade top (score:0.4608316087438084)
#
#
#
#
# Recommending 10 products similar to L/s sol patrol shirt with threshold 0.2...
# -------
# Recommended: S/s sol patrol shirt (score:0.6346209165826867)
# Recommended: S/s sol patrol shirt (score:0.20941677738118808)
#
#
#
#
# Recommending 10 products similar to Bimini cap with threshold 0.2...
# -------
# Recommended: Logo visor (score:0.31647259059574284)
# Recommended: Velocity visor (score:0.28697284108739224)
# Recommended: Velocity cap (score:0.26695066186505606)
#
#
#
#
# Recommending 10 products similar to Borderless messenger shorts with threshold 0.2...
# -------
# Recommended: Borderless trek pants (score:0.4663159422107404)
# Recommended: Borderless trek zip-off pants (score:0.44340970769084953)
# Recommended: Borderless shorts-7 in. (score:0.40762233939622655)
# Recommended: Borderless shorts-11 in. (score:0.39590724149738954)
#
#
#
#
# Recommending 10 products similar to Duck pants with threshold 0.2...
# -------
# Recommended: Duck pants (score:0.9152592469250164)
# Recommended: Duck pants (score:0.9129682337046948)
# Recommended: Duck shorts (score:0.3394626502655502)
# Recommended: Custodian pants (score:0.2678540375498264)
# Recommended: Custodian pants (score:0.2413993518803114)
# Recommended: Custodian pants (score:0.24097796450892398)
# Recommended: All-wear shorts (score:0.2011594789396918)
#
#
#
#
# Recommending 10 products similar to Duck pants with threshold 0.2...
# -------
# Recommended: Duck pants (score:0.9152592469250164)
# Recommended: Duck pants (score:0.9139073627612282)
# Recommended: Duck shorts (score:0.33843139324703436)
# Recommended: Custodian pants (score:0.270346922978866)
# Recommended: Custodian pants (score:0.24170503877349173)
# Recommended: Custodian pants (score:0.24153816219029706)
# Recommended: All-wear shorts (score:0.2015152576360127)
#
#
#
#
# Recommending 10 products similar to Duck shorts with threshold 0.2...
# -------
# Recommended: Duck pants (score:0.3394626502655502)
# Recommended: Duck pants (score:0.33843139324703436)
# Recommended: Duck pants (score:0.33733748601845526)
# Recommended: All-wear shorts (score:0.23425464417479197)
# Recommended: Custodian pants (score:0.2240042485246181)
# Recommended: Custodian pants (score:0.222272629046621)
# Recommended: Custodian pants (score:0.2220122238564869)
# Recommended: All-wear cargo shorts (score:0.21428852481172805)
#
#
#
#
# Recommending 10 products similar to Borderless trek pants with threshold 0.2...
# -------
# Recommended: Borderless trek zip-off pants (score:0.49947914304331936)
# Recommended: Borderless messenger shorts (score:0.4663159422107404)
# Recommended: Borderless shorts-7 in. (score:0.4112760613436212)
# Recommended: Borderless shorts-11 in. (score:0.4000318829835315)
# Recommended: Borderless pants (score:0.2288472202115073)
#
#
#
#
# Recommending 10 products similar to Borderless trek zip-off pants with threshold 0.2...
# -------
# Recommended: Borderless trek pants (score:0.49947914304331936)
# Recommended: Borderless messenger shorts (score:0.44340970769084953)
# Recommended: Borderless shorts-11 in. (score:0.3914341729774648)
# Recommended: Borderless shorts-7 in. (score:0.3839531725451692)
# Recommended: Gi ii zip-off pants (score:0.24160632255165532)
# Recommended: Borderless pants (score:0.2122148526583244)
# Recommended: Borderless zip-off pants (score:0.21082586197677408)
#
#
#
#
# Recommending 10 products similar to Half mass with threshold 0.2...
# -------
# Recommended: Critical mass (score:0.8079611956533287)
# Recommended: Lightwire brief (score:0.2334516670281043)
# Recommended: Minimass (score:0.2234399716864217)
# Recommended: Lightwire (score:0.21050981717675044)
# Recommended: Daily grind (score:0.20575646632840955)
#
#
#
#
# Recommending 10 products similar to Cap 1 crew with threshold 0.2...
# -------
# Recommended: Cap 1 t-shirt (score:0.5911193687131717)
# Recommended: Cap 1 graphic t-shirt (score:0.5607101445490794)
# Recommended: Cap 1 graphic crew (score:0.5547403166797779)
# Recommended: Cap 1 scoop (score:0.5465249660914732)
# Recommended: Cap 1 t-shirt (score:0.5341938228481482)
# Recommended: Cap 1 graphic t-shirt (score:0.48873318694564677)
# Recommended: Cap 1 bottoms (score:0.4398452473875057)
# Recommended: Cap 1 bottoms (score:0.4302834865649564)
# Recommended: Cap 1 graphic tee (score:0.28973177473988854)
#
#
#
#
# Recommending 10 products similar to Cap 1 graphic crew with threshold 0.2...
# -------
# Recommended: Cap 1 graphic t-shirt (score:0.6627265635417604)
# Recommended: Cap 1 t-shirt (score:0.600356551465248)
# Recommended: Cap 1 graphic t-shirt (score:0.5726931799264072)
# Recommended: Cap 1 crew (score:0.5547403166797779)
# Recommended: Cap 1 t-shirt (score:0.5122701521239463)
# Recommended: Cap 1 scoop (score:0.4586224268780683)
# Recommended: Cap 1 bottoms (score:0.41612615842222556)
# Recommended: Cap 1 bottoms (score:0.41408585242678553)
# Recommended: Cap 1 graphic tee (score:0.2566889186685085)
#
#
#
#
# Recommending 10 products similar to Fitz roy study t-shirt with threshold 0.2...
# -------
# Recommended: Planer t-shirt (score:0.3127972847815611)
# Recommended: Rockpile t-shirt (score:0.3060635506391843)
# Recommended: Iceberg t-shirt (score:0.291213559369713)
# Recommended: Yosemite essence t-shirt (score:0.2871734298107539)
# Recommended: Text logo t-shirt (score:0.28618455366454315)
# Recommended: Flying fish 2 t-shirt (score:0.2812956245636318)
# Recommended: Trout silhouette t-shirt (score:0.2783573301746075)
# Recommended: Trout head t-shirt (score:0.2773179501932903)
# Recommended: Wind path t-shirt (score:0.2772350748576385)
# Recommended: Tarpon t-shirt (score:0.2695412726959288)
#
#
#
#
# Recommending 10 products similar to Flyfishing the athabasca poster with threshold 0.2...
# -------
# Recommended: Traversing auguille d'entreves (score:0.6575417810162217)
# Recommended: Symmetry w16 poster (score:0.6544478894872702)
# Recommended: Lead an examined life poster (score:0.6294065125011532)
# Recommended: Wyoming climbing poster (score:0.6132529577602621)
# Recommended: Wild steelhead, alaska poster (score:0.5845439053271259)
# Recommended: Going big in b.c. poster (score:0.5795434474319086)
# Recommended: Sticks 'n stones morocco poster (score:0.5375184762507991)
#
#
#
#
# Recommending 10 products similar to Flying fish 2 t-shirt with threshold 0.2...
# -------
# Recommended: Rockpile t-shirt (score:0.4014908688123496)
# Recommended: Live simply deer t-shirt (score:0.40033658215464735)
# Recommended: The more you know t-shirt (score:0.39132643707806586)
# Recommended: Organic logo t-shirt (score:0.3762839603261779)
# Recommended: Wind path t-shirt (score:0.37530799188640945)
# Recommended: Squid t-shirt (score:0.37354748369308727)
# Recommended: City by the sea t-shirt (score:0.3677792235783415)
# Recommended: Live simply guitar t-shirt (score:0.3626377950999974)
# Recommended: Dragoons t-shirt (score:0.360657733483138)
# Recommended: Mountain island t-shirt (score:0.3528309437678981)
#
#
#
#
# Recommending 10 products similar to Freedom to roam t-shirt with threshold 0.2...
# -------
# Recommended: Freedom to roam t-shirt (score:0.9812622733833956)
# Recommended: Rockpile t-shirt (score:0.2546019058126156)
# Recommended: Iceberg t-shirt (score:0.25196878478551793)
# Recommended: Peregrine t-shirt (score:0.24033174994759776)
# Recommended: Text logo t-shirt (score:0.23862073502004136)
# Recommended: Wind path t-shirt (score:0.22744185912550005)
# Recommended: Live simply deer t-shirt (score:0.2268931821430218)
# Recommended: Trout head t-shirt (score:0.22502819128156717)
# Recommended: Flying fish 2 t-shirt (score:0.22380592838371657)
# Recommended: Tarpon t-shirt (score:0.22049973980630735)
#
#
#
#
# Recommending 10 products similar to '73 logo t-shirt with threshold 0.2...
# -------
# Recommended: Text logo t-shirt (score:0.41799583857100375)
# Recommended: Rockpile t-shirt (score:0.3899339169097087)
# Recommended: Vintage logo pkt t-shirt (score:0.3561147405636255)
# Recommended: Organic logo t-shirt (score:0.3460870591948347)
# Recommended: Iceberg t-shirt (score:0.33071464050933724)
# Recommended: City by the sea t-shirt (score:0.32960720857635634)
# Recommended: Owlin around t-shirt (score:0.3290288716943124)
# Recommended: Wheat t-shirt (score:0.32841863817677536)
# Recommended: Trout head t-shirt (score:0.3277370787941036)
# Recommended: Flying fish 2 t-shirt (score:0.32476665434591157)
#
#
#
#
# Recommending 10 products similar to Active boxer briefs with threshold 0.2...
# -------
# Recommended: Cap 1 boxer briefs (score:0.5283612680341314)
# Recommended: Active briefs (score:0.31168448452486075)
# Recommended: Cap 2 bottoms (score:0.21715707081717894)
# Recommended: Cap 2 bottoms (score:0.21442279840079453)
#
#
#
#
# Recommending 10 products similar to Active briefs with threshold 0.2...
# -------
# Recommended: Active boxer briefs (score:0.31168448452486075)
# Recommended: Cap 2 bottoms (score:0.2400276436998116)
# Recommended: Cap 2 bottoms (score:0.22228532905649107)
# Recommended: Cap 1 boxer briefs (score:0.22221365425398973)
# Recommended: Cap 2 zip neck (score:0.20919722559151838)
# Recommended: Cap 2 crew (score:0.20473993519440054)
# Recommended: Cap 2 t-shirt (score:0.20012072531614)
#
#
#
#
# Recommending 10 products similar to Cap 2 bottoms with threshold 0.2...
# -------
# Recommended: Cap 2 bottoms (score:0.615185258187686)
# Recommended: Cap 2 t-shirt (score:0.41582263836147854)
# Recommended: Cap 2 zip neck (score:0.3858009796517637)
# Recommended: Cap 2 cap sleeve (score:0.3836777450950878)
# Recommended: Cap 2 crew (score:0.38356142106852953)
# Recommended: Cap 2 t-shirt (score:0.3723038081114073)
# Recommended: Cap 2 zip neck (score:0.33874337630298856)
# Recommended: Cap 2 v-neck (score:0.33541585404245494)
# Recommended: Cap 3 bottoms (score:0.3002635911201806)
# Recommended: Cap 3 bottoms (score:0.255209064611744)
#
#
#
#
# Recommending 10 products similar to Cap 2 crew with threshold 0.2...
# -------
# Recommended: Cap 2 t-shirt (score:0.7049890803634628)
# Recommended: Cap 2 t-shirt (score:0.6334452370495761)
# Recommended: Cap 2 cap sleeve (score:0.6081146129427671)
# Recommended: Cap 2 zip neck (score:0.5672627008820263)
# Recommended: Cap 2 zip neck (score:0.5308649780944353)
# Recommended: Cap 2 v-neck (score:0.5148329784985639)
# Recommended: Cap 2 bottoms (score:0.38356142106852953)
# Recommended: Cap 2 bottoms (score:0.37226731482237774)
# Recommended: Cap 3 crew (score:0.3038439419387368)
# Recommended: Cap 3 crew (score:0.2608243059380334)
#
#
#
#
# Recommending 10 products similar to All-time shell with threshold 0.2...
# -------
# Recommended: All-time shell (score:0.2374715687767636)
# Recommended: Storm light jkt (score:0.2269740586128968)
# Recommended: Storm light jkt (score:0.22636494598983972)
#
#
#
#
# Recommending 10 products similar to All-wear cargo shorts with threshold 0.2...
# -------
# Recommended: Custodian pants (score:0.38624756584794606)
# Recommended: Custodian pants (score:0.3842216752132679)
# Recommended: Custodian pants (score:0.38377153738560726)
# Recommended: All-wear shorts (score:0.3628162618600101)
# Recommended: Delivery shorts (score:0.28349723689192663)
# Recommended: Compound cargo shorts (score:0.2183189256701979)
# Recommended: All-wear capris (score:0.217008656335211)
# Recommended: Duck shorts (score:0.21428852481172805)

# %%
data = pd.read_csv('ml-latest-small/movies.csv')
data.info()
print('')
print('')


ratings = pd.read_csv('ml-latest-small/ratings.csv')
del ratings['timestamp']
ratings.info()
print('')
print('')

tags = pd.read_csv('ml-latest-small/tags.csv')
del tags['timestamp']
tags.info()
print('')
print('')

#Joining movies and ratings

movies_data = data.merge(ratings, on = 'movieId', how = 'inner')

#movies_data.info()
#movies_data.isnull().any()
#print(len(movies_data['movieId'].unique().tolist()))

# dropping duplicate  moviId as the recommender system takes input for item(movieId here) and will give recommendation 
# based on tags in single text stream, not multiple rows of duplicate item.

movies_data = movies_data.drop_duplicates(subset = ['movieId'])
print('No of unique moviId in merged datset')
print(len(movies_data['movieId'].unique().tolist()))
print('')
print('')
movies_data.info()
print('')
print('')

#Joining movies_data and tags
tags = tags.drop_duplicates(subset = ['movieId'])
tags.info()

movies_data_tags = movies_data.merge(tags, on ='movieId', how = 'inner')
movies_data_tags.head()

#1554 unique movies with tags
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
# movieId    9742 non-null int64
# title      9742 non-null object
# genres     9742 non-null object
# dtypes: int64(1), object(2)
# memory usage: 228.5+ KB
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 3 columns):
# userId     100836 non-null int64
# movieId    100836 non-null int64
# rating     100836 non-null float64
# dtypes: float64(1), int64(2)
# memory usage: 2.3 MB
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3683 entries, 0 to 3682
# Data columns (total 3 columns):
# userId     3683 non-null int64
# movieId    3683 non-null int64
# tag        3683 non-null object
# dtypes: int64(2), object(1)
# memory usage: 86.4+ KB
#
#
# No of unique moviId in merged datset
# 9724
#
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9724 entries, 0 to 100835
# Data columns (total 5 columns):
# movieId    9724 non-null int64
# title      9724 non-null object
# genres     9724 non-null object
# userId     9724 non-null int64
# rating     9724 non-null float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 455.8+ KB
#
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1572 entries, 0 to 3680
# Data columns (total 3 columns):
# userId     1572 non-null int64
# movieId    1572 non-null int64
# tag        1572 non-null object
# dtypes: int64(2), object(1)
# memory usage: 49.1+ KB
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        5  Father of the Bride Part II (1995)
# 4        7                      Sabrina (1995)
#
#                                         genres  userId_x  rating  userId_y  \
# 0  Adventure|Animation|Children|Comedy|Fantasy         1     4.0       336
# 1                   Adventure|Children|Fantasy         6     4.0        62
# 2                               Comedy|Romance         1     4.0       289
# 3                                       Comedy         6     5.0       474
# 4                               Comedy|Romance         6     4.0       474
#
#          tag
# 0      pixar
# 1    fantasy
# 2      moldy
# 3  pregnancy
# 4     remake

# %% [markdown]
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.metrics.pairwise import linear_kernel
#
# # 1. calculates tf-idf scores for items
# tf = TfidfVectorizer(analyzer='word', ngram_range=(1, 3), min_df=0, stop_words='english')
# tfidf_matrix = tf.fit_transform(movies_data_tags['tag'])
#
#
# # 2. Calculate cosine similarity
# cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)
# results = {}
#
# # 3. Saving results in order of similarity to item i
#
# for idx, row in movies_data_tags.iterrows():
#     similar_indices = cosine_similarities[idx].argsort()[:-100:-1]
#     similar_items = [(cosine_similarities[idx][i], movies_data_tags['tag'][i]) for i in similar_indices]
#
#     results[row['movieId']] = similar_items[1:]
#
# print('Saved')
# print(results)
# #def item(id):
# #return movies_data_tags.loc[movies_data_tags['movieId'] == id]
#
# # 4.a Just reads the results out of the dictionary.
# def recommend(item_id, num, threshold):
#     #print("Recommending " + str(num) + " products similar to " + movies_data_tags['movieId'] == item_id + "...")
#     #print("-------")
#     recs = results[item_id][:num]
#     for rec in recs:
#
#         # A condition can be added to only to print items above a similairty threshold (50% etc.)
#         if(rec[0]>threshold):
#             print("Recommended: " + item(rec[1]) + " (score:" + str(rec[0]) + ")")
#
# # 4. Recommend items similar to item_id and num = number of recommendations with a similarity threshold value
#
#
# recommend(item_id=1, num=5, threshold= 0.3)  # Recommend  5 items similar to item_id 9 with similarity of >30%
# print('')
# print('')
# print('')
# recommend(item_id=3, num=10, threshold= 0.5) # Recommend  10 items similar to item_id 22 with similarity of >50%
