# %% [markdown]
# # Requirements of Totality  Corp:
# <b>Assignment 1 </b><br>(Design Recommendation System Architecture)<br>
# Content discovery is a vital part for the Yovo. Users often don't know what they want to watch and need a way to discover content without searching for it. <b>Create a feed personalisation algorithm strategy which enables users to discover the right content. Underlying algorithm must strike an elegant balance between Machine Learning and giving the user control over what content they want to see.</b>
# Note:
# - Video has certain text attributes: tags, category, title text (context) - Use pseudocode wherever necessary
# - Download ​yovo app​ to see actual feed

# %% [markdown]
# # Potential solutions to the problem:
#
# ### Recommender Systems generally follow one of two methods:
# ##### 1. Collaborative filtering
#
# This approach <b> will not apply to the Yovo app as there is no option for users to like certain videos in their feed.
# The approach would require the app to keep track of each user and their likes, shares etc. in the form of user matrix. </b>
#
#
# ##### 2. Content Based filtering (Suitable for YOVO app)
#
# This approach utilizes a series of discrete characteristics of an item in order to recommend additional items with similar properties.
#
# <b>Based on items,which are videos in the case of Yovo including the characteristics - tags, category, title text (context) in this case.
#
# This method is suitable in the case where metadata is available and no matrix of users ids, preferences is available.</b>

# %% [markdown]
# # Practical Example of Content based filtering (Architecture) :
#
# ## The Dataset
#
# The dataset of 500 entries of different items like shoes, shirts etc., along with an item-id and a <b>textual description of the item.</b><br>
# The system creates a profile for each item and recommends similar items.
#
# <b>For totality, I imagine this dataset will be replaced with one containing textual discription of the video(videoId)
# using the tags or title  attributes.</b>
#
# ## Process
#
# #### 1. Extract TF * IDF [(term frequency)*(Inverse document frequency)] Score
#
# The TF*IDF algorithm finds the importance of a word in the tag. This is done for each word in the tag and for each item.<br>
# <b>This is implemented using scikit-learns inbuilt TF-IDF vectorizer. </b>
#
# #### 2. Calculating Similarity using Cosine Similarity
# Once we have the vectors for each item, we can use cosine similarity to find items/ words that are similar.<br>
# Cosine similarity judges how close the cosine angles are in the vector representation of the items.<br>
#
# <b>This is done using the linear_kernel method of scikit-learn. It takes the tfidf matrix of the items as input and compares them to find items that are similar. </b>
#
# #### 3. Store results of cosine similarity
# The results of cosine similarity are stored in result, arranged according to similarity with item i.
#
# #### 4. Recommending Items
# The function recommend takes in the item for which a recommendation is to be made and the number of recommmendations to be made and reads out the most similar items from results.
# <br>
# We input a threshold value to only get recommendation above a certain similarity index.<br>
# <b> The items recommended can then be fed into the personalized feed of the user for relevant video recommendations.</b>

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel 

# reads dataset 
ds = pd.read_csv("sample-data.csv")

ds.head()

# 1. calculates tf-idf scores for items
tf = TfidfVectorizer(analyzer='word', ngram_range=(1, 3), min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(ds['description'])


# 2. Calculate cosine similarity 
cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix) 
results = {}

# 3. Saving results in order of similarity to item i to dictionary results

for idx, row in ds.iterrows():
    similar_indices = cosine_similarities[idx].argsort()[:-100:-1]
    similar_items = [(cosine_similarities[idx][i], ds['id'][i]) for i in similar_indices]

    results[row['id']] = similar_items[1:]

print('Saved')

def item(id):
    return ds.loc[ds['id'] == id]['description'].tolist()[0].split(' - ')[0]

# 4.a Just reads the results out of the dictionary.
def recommend(item_id, num, threshold):
    print("Recommending " + str(num) + " products similar to " + item(item_id) + " with threshold " + str(threshold) + "...")
    print("-------")
    recs = results[item_id][:num]
    for rec in recs:
        
        # A condition can be added to only to print items above a similairty threshold (50% etc.)
        if(rec[0]>threshold):
            print("Recommended: " + item(rec[1]) + " (score:" + str(rec[0]) + ")")

# 4. Recommend items similar to item_id and num = number of recommendations with a similarity threshold value 


recommend(item_id=9, num=5, threshold= 0.3)  # Recommend  5 items similar to item_id 9 with similarity of >30%
print('')
print('')
print('')
recommend(item_id=22, num=10, threshold= 0.5) # Recommend  10 items similar to item_id 22 with similarity of >50%
for itemid in range(1,500):
    recommend(item_id=itemid, num=10, threshold= 0.5)
    print('')
    print('')
# Out:
# Saved
# Recommending 5 products similar to Baby micro d-luxe cardigan... with threshold 0.3
# -------
# Recommended: Micro d-luxe cardigan (score:0.37550840843454325)
#
#
#
# Recommending 10 products similar to Cap 2 t-shirt... with threshold 0.5
# -------
# Recommended: Cap 2 crew (score:0.7049890803634637)
# Recommended: Cap 2 t-shirt (score:0.7041906217524195)
# Recommended: Cap 2 cap sleeve (score:0.6635362790007241)
# Recommended: Cap 2 zip neck (score:0.6225162259563587)
# Recommended: Cap 2 zip neck (score:0.5295225236280288)
# Recommended: Cap 2 v-neck (score:0.5094581638236453)
# Recommending 10 products similar to Active classic boxers... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Active sport boxer briefs... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Active sport briefs... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Alpine guide pants... with threshold 0.5
# -------
# Recommended: Alpine guide pants (score:0.8253856759948807)
#
#
# Recommending 10 products similar to Alpine wind jkt... with threshold 0.5
# -------
# Recommended: Alpine wind jkt (score:0.9550036493156216)
#
#
# Recommending 10 products similar to Ascensionist jkt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Atom... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Print banded betina btm... with threshold 0.5
# -------
# Recommended: Solid betina btm (score:0.9132682180464679)
#
#
# Recommending 10 products similar to Baby micro d-luxe cardigan... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Baby sun bucket hat... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Baby sunshade top... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Baggies shorts... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Beach bucket... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Better sweater jkt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Borderless shorts-11 in.... with threshold 0.5
# -------
# Recommended: Borderless shorts-7 in. (score:0.5292087918224079)
#
#
# Recommending 10 products similar to Borderless shorts-7 in.... with threshold 0.5
# -------
# Recommended: Borderless shorts-11 in. (score:0.5292087918224079)
#
#
# Recommending 10 products similar to Bucket hat... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Cap 1 bottoms... with threshold 0.5
# -------
# Recommended: Cap 1 bottoms (score:0.5651753677668038)
#
#
# Recommending 10 products similar to Cap 1 boxer briefs... with threshold 0.5
# -------
# Recommended: Active boxer briefs (score:0.5283612680341317)
#
#
# Recommending 10 products similar to Cap 1 graphic t-shirt... with threshold 0.5
# -------
# Recommended: Cap 1 graphic t-shirt (score:0.6681227479230913)
# Recommended: Cap 1 graphic crew (score:0.6627265635417637)
# Recommended: Cap 1 t-shirt (score:0.620927028466331)
# Recommended: Cap 1 crew (score:0.5607101445490805)
# Recommended: Cap 1 t-shirt (score:0.5374827505943768)
#
#
# Recommending 10 products similar to Cap 1 t-shirt... with threshold 0.5
# -------
# Recommended: Cap 1 graphic t-shirt (score:0.620927028466331)
# Recommended: Cap 1 graphic crew (score:0.6003565514652496)
# Recommended: Cap 1 crew (score:0.5911193687131718)
# Recommended: Cap 1 t-shirt (score:0.5766557156725726)
# Recommended: Cap 1 scoop (score:0.5034580391792775)
#
#
# Recommending 10 products similar to Cap 2 t-shirt... with threshold 0.5
# -------
# Recommended: Cap 2 crew (score:0.7049890803634637)
# Recommended: Cap 2 t-shirt (score:0.7041906217524195)
# Recommended: Cap 2 cap sleeve (score:0.6635362790007241)
# Recommended: Cap 2 zip neck (score:0.6225162259563587)
# Recommended: Cap 2 zip neck (score:0.5295225236280288)
# Recommended: Cap 2 v-neck (score:0.5094581638236453)
#
#
# Recommending 10 products similar to Cap 2 zip neck... with threshold 0.5
# -------
# Recommended: Cap 2 zip neck (score:0.6344950850896238)
# Recommended: Cap 2 t-shirt (score:0.6225162259563587)
# Recommended: Cap 2 t-shirt (score:0.5692208052197045)
# Recommended: Cap 2 crew (score:0.567262700882027)
# Recommended: Cap 2 cap sleeve (score:0.5669850877868137)
#
#
# Recommending 10 products similar to Cap 3 zip neck... with threshold 0.5
# -------
# Recommended: Cap 3 crew (score:0.6843679481573053)
# Recommended: Cap 3 crew (score:0.6309802636575091)
#
#
# Recommending 10 products similar to Cap 4 bottoms... with threshold 0.5
# -------
# Recommended: Cap 4 bottoms (score:0.6573821798739578)
# Recommended: Cap 4 zip neck (score:0.5308507649075489)
#
#
# Recommending 10 products similar to City by the sea t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Compound cargo pants... with threshold 0.5
# -------
# Recommended: Compound cargo pants (score:0.9333114560598277)
# Recommended: Compound cargo pants (score:0.9325715856217304)
# Recommended: Compound cargo shorts (score:0.5092629518557467)
#
#
# Recommending 10 products similar to Compound cargo pants... with threshold 0.5
# -------
# Recommended: Compound cargo pants (score:0.9405490620389069)
# Recommended: Compound cargo pants (score:0.9333114560598277)
# Recommended: Compound cargo shorts (score:0.5117925102595451)
#
#
# Recommending 10 products similar to Continental shorts... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Cotton board shorts... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Crosstown... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Custodian pants... with threshold 0.5
# -------
# Recommended: Custodian pants (score:0.9032073991345063)
# Recommended: Custodian pants (score:0.9020484306816423)
#
#
# Recommending 10 products similar to Deep wading jkt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Delivery shorts... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Down sweater vest... with threshold 0.5
# -------
# Recommended: Down sweater vest (score:0.814592917925505)
# Recommended: Down sweater (score:0.5316112056797005)
#
#
# Recommending 10 products similar to Dragoons t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Duck pants... with threshold 0.5
# -------
# Recommended: Duck pants (score:0.9139073627612257)
# Recommended: Duck pants (score:0.9129682337046908)
#
#
# Recommending 10 products similar to Elias fz sweatshirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Elias sweatshirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Fezzman shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Fish frenzy t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Freewheeler... with threshold 0.5
# -------
# Recommended: Freewheeler max (score:0.6896990390185027)
#
#
# Recommending 10 products similar to Gi ii pants... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Gi ii shorts... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Girl's boardie capris... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Girl's boardie shorts... with threshold 0.5
# -------
# Recommended: Boardie shorts (score:0.5966928925110491)
#
#
# Recommending 10 products similar to Girl's cotton tank dress... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Going big in b.c. poster... with threshold 0.5
# -------
# Recommended: Wyoming climbing poster (score:0.721611581668574)
# Recommended: Wild steelhead, alaska poster (score:0.6836354384876687)
# Recommended: Sticks 'n stones morocco poster (score:0.6351296822709638)
# Recommended: Lead an examined life poster (score:0.6059523396930557)
# Recommended: Symmetry w16 poster (score:0.5937018934480086)
# Recommended: Flyfishing the athabasca poster (score:0.5795434474319056)
# Recommended: Traversing auguille d'entreves (score:0.5680388827752251)
#
#
# Recommending 10 products similar to Great divider... with threshold 0.5
# -------
# Recommended: Sub divider (score:0.6735109210642198)
#
#
# Recommending 10 products similar to Guidewater duffle... with threshold 0.5
# -------
# Recommended: Guidewater duffle (score:0.6895541163108592)
#
#
# Recommending 10 products similar to Guidewater jkt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Guidewater shorts... with threshold 0.5
# -------
# Recommended: Guidewater pants (score:0.7214291304557571)
#
#
# Recommending 10 products similar to Guidewater vest... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Highwater pfd vest... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Hip chest pack... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Iceberg t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Insulator pants... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to '73 logo t-shirt... with threshold 0.5
# -------
# Recommended: Flying fish t-shirt (score:0.9108243808208851)
# Recommended: Gpiw classic t-shirt (score:0.90535306836541)
# Recommended: Live simply guitar t-shirt (score:0.8961878040125465)
# Recommended: Girl's live simply deer t-shirt (score:0.8100918892193384)
# Recommended: Girl's live simply seal t-shirt (score:0.8072652420751544)
#
#
# Recommending 10 products similar to Borderless gi shorts... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Cap 1 graphic tee... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Cap 3 bottoms... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to El cap jkt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Flying fish t-shirt... with threshold 0.5
# -------
# Recommended: '73 logo t-shirt (score:0.9108243808208851)
# Recommended: Gpiw classic t-shirt (score:0.901594544659202)
# Recommended: Live simply guitar t-shirt (score:0.8924673293996112)
# Recommended: Girl's live simply deer t-shirt (score:0.80672883708396)
# Recommended: Girl's live simply seal t-shirt (score:0.8039139246106713)
#
#
# Recommending 10 products similar to Gpiw classic t-shirt... with threshold 0.5
# -------
# Recommended: '73 logo t-shirt (score:0.90535306836541)
# Recommended: Flying fish t-shirt (score:0.901594544659202)
# Recommended: Live simply guitar t-shirt (score:0.8871062875585407)
# Recommended: Girl's live simply deer t-shirt (score:0.8018828254625427)
# Recommended: Girl's live simply seal t-shirt (score:0.7990848221388119)
#
#
# Recommending 10 products similar to Live simply guitar t-shirt... with threshold 0.5
# -------
# Recommended: '73 logo t-shirt (score:0.8961878040125465)
# Recommended: Flying fish t-shirt (score:0.8924673293996112)
# Recommended: Gpiw classic t-shirt (score:0.8871062875585407)
# Recommended: Girl's live simply deer t-shirt (score:0.8202636525774637)
# Recommended: Girl's live simply seal t-shirt (score:0.817401513180821)
#
#
# Recommending 10 products similar to Synch marsupial... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Torrentshell jkt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to La surfer maria t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Lead an examined life poster... with threshold 0.5
# -------
# Recommended: Symmetry w16 poster (score:0.7617394854137104)
# Recommended: Wyoming climbing poster (score:0.6411979399045455)
# Recommended: Flyfishing the athabasca poster (score:0.6294065125011518)
# Recommended: Traversing auguille d'entreves (score:0.6171464361249778)
# Recommended: Wild steelhead, alaska poster (score:0.6074537132434243)
# Recommended: Going big in b.c. poster (score:0.6059523396930557)
# Recommended: Sticks 'n stones morocco poster (score:0.5647187318326249)
#
#
# Recommending 10 products similar to Light and variable surf trunks... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Live simply bug t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Live simply deer t-shirt... with threshold 0.5
# -------
# Recommended: Live simply deer t-shirt (score:0.8572941375329484)
# Recommended: Baby live simply deer t-shirt (score:0.5116094608869223)
#
#
# Recommending 10 products similar to Live simply guitar t-shirt... with threshold 0.5
# -------
# Recommended: Live simply guitar t-shirt (score:0.813216776182424)
#
#
# Recommending 10 products similar to Logo hat... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to L/s hooded rashguard... with threshold 0.5
# -------
# Recommended: L/s rashguard (score:0.7384779509677872)
# Recommended: S/s rashguard (score:0.7173507095210117)
#
#
# Recommending 10 products similar to L/s island hopper shirt... with threshold 0.5
# -------
# Recommended: S/s island hopper shirt (score:0.8013463830281654)
#
#
# Recommending 10 products similar to L/s rashguard... with threshold 0.5
# -------
# Recommended: S/s rashguard (score:0.9533710538575074)
# Recommended: L/s hooded rashguard (score:0.7384779509677872)
#
#
# Recommending 10 products similar to L/s steersman shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Lw endurance ankle socks... with threshold 0.5
# -------
# Recommended: Lw endurance quarter socks (score:0.6209215860873725)
#
#
# Recommending 10 products similar to Lw endurance quarter socks... with threshold 0.5
# -------
# Recommended: Lw endurance ankle socks (score:0.6209215860873725)
#
#
# Recommending 10 products similar to Lw hiking crew socks... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Lw r4 jkt... with threshold 0.5
# -------
# Recommended: Lw r4 jkt (score:0.9252465651645179)
#
#
# Recommending 10 products similar to Lw travel duffel... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Lw travel pack... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to M10 jkt... with threshold 0.5
# -------
# Recommended: M10 jkt (score:0.9322179611179894)
#
#
# Recommending 10 products similar to M10 pants... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Merino 1 crew... with threshold 0.5
# -------
# Recommended: Merino 1 t-shirt (score:0.6490161598583365)
# Recommended: Merino 1 crew (score:0.6385540623104623)
# Recommended: Merino 1 graphic t-shirt (score:0.6168376730361487)
# Recommended: Merino 1 t-shirt (score:0.6142503723031506)
# Recommended: Merino 1 tank (score:0.579553880179159)
# Recommended: Merino 2 crew (score:0.5312127545245438)
#
#
# Recommending 10 products similar to Merino 1 t-shirt... with threshold 0.5
# -------
# Recommended: Merino 1 crew (score:0.7559689146017289)
# Recommended: Merino 1 t-shirt (score:0.7005765371335269)
# Recommended: Merino 1 graphic t-shirt (score:0.6983391545795754)
# Recommended: Merino 1 tank (score:0.6738398804186714)
# Recommended: Merino 1 crew (score:0.6490161598583365)
#
#
# Recommending 10 products similar to Merino 2 polo... with threshold 0.5
# -------
# Recommended: Merino 2 t-shirt (score:0.6627218930438891)
# Recommended: Merino 2 bottoms (score:0.6323953372141051)
# Recommended: Merino 2 bottoms (score:0.6121277706073268)
# Recommended: Merino 2 crew (score:0.6018782098696162)
# Recommended: Merino 2 crew (score:0.5683494594687439)
# Recommended: Merino 2 t-shirt (score:0.5474223305741497)
# Recommended: Merino 2 dress (score:0.5266566579166626)
#
#
# Recommending 10 products similar to Merino 2 t-shirt... with threshold 0.5
# -------
# Recommended: Merino 2 crew (score:0.7387583673473282)
# Recommended: Merino 2 polo (score:0.6627218930438891)
# Recommended: Merino 2 bottoms (score:0.6433303120933126)
# Recommended: Merino 2 bottoms (score:0.6354414878769347)
# Recommended: Merino 2 t-shirt (score:0.621345407638338)
# Recommended: Merino 2 crew (score:0.6097511363106211)
# Recommended: Merino 2 dress (score:0.5396530354364177)
#
#
# Recommending 10 products similar to Migration hemp shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Minimalist board shorts-19 in.... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Minimass... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Mlc wheelie... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Mountain island t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Nine trails jkt... with threshold 0.5
# -------
# Recommended: Nine trails jkt (score:0.8664478880889579)
# Recommended: Nine trails vest (score:0.5450655230186493)
# Recommended: Nine trails vest (score:0.5415288245928032)
#
#
# Recommending 10 products similar to Nine trails shorts... with threshold 0.5
# -------
# Recommended: Nine trails shorts (score:0.7427820064015012)
#
#
# Recommending 10 products similar to Organic logo t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to O web belt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Paddler board shorts... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Pataloha shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Planer t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Platform t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Pocket pack... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to R1 hoody... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to R1 p/o... with threshold 0.5
# -------
# Recommended: R1 p/o (score:0.6950899841063927)
#
#
# Recommending 10 products similar to Rain shadow pants... with threshold 0.5
# -------
# Recommended: Rain shadow pants (score:0.9862089082808871)
#
#
# Recommending 10 products similar to Reg fit organic ctn jeans-long... with threshold 0.5
# -------
# Recommended: Reg fit organic ctn jeans-reg (score:0.9534878451758867)
# Recommended: Reg fit organic ctn jeans-short (score:0.9522246792960233)
# Recommended: Relax fit organic ctn jeans-long (score:0.5228366582772286)
#
#
# Recommending 10 products similar to Reg fit organic ctn jeans-reg... with threshold 0.5
# -------
# Recommended: Reg fit organic ctn jeans-short (score:0.9536045210725154)
# Recommended: Reg fit organic ctn jeans-long (score:0.9534878451758867)
# Recommended: Relax fit organic ctn jeans-reg (score:0.5218538039979262)
#
#
# Recommending 10 products similar to Relax fit organic ctn jeans-shor... with threshold 0.5
# -------
# Recommended: Relax fit organic ctn jeans-reg (score:0.8908101955877065)
# Recommended: Relax fit organic ctn jeans-long (score:0.8866113828050025)
# Recommended: Reg fit organic ctn jeans-short (score:0.507668259865595)
#
#
# Recommending 10 products similar to Remat... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Retro grade pants... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Riverwalker... with threshold 0.5
# -------
# Recommended: Riverwalker (score:0.9010967838251577)
# Recommended: Riverwalker (score:0.8828362580958543)
# Recommended: Marlwalker (score:0.5563240857708249)
#
#
# Recommending 10 products similar to Riverwalker... with threshold 0.5
# -------
# Recommended: Riverwalker (score:0.9010967838251577)
# Recommended: Riverwalker (score:0.8864260498971591)
# Recommended: Marlwalker (score:0.5627754776157905)
#
#
# Recommending 10 products similar to Rock guide shorts... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Rockpile t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Runshade top... with threshold 0.5
# -------
# Recommended: L/s runshade top (score:0.6118589217273243)
# Recommended: Runshade t-shirt (score:0.538621496987378)
# Recommended: Runshade t-shirt (score:0.5299142171988557)
#
#
# Recommending 10 products similar to Shop pants... with threshold 0.5
# -------
# Recommended: Shop pants (score:0.9087533173001199)
# Recommended: Shop pants (score:0.9085259342535011)
#
#
# Recommending 10 products similar to Shop pants... with threshold 0.5
# -------
# Recommended: Shop pants (score:0.9087533173001199)
# Recommended: Shop pants (score:0.9087343193828873)
#
#
# Recommending 10 products similar to Simple guide jkt... with threshold 0.5
# -------
# Recommended: Simple guide jkt (score:0.9280413287811633)
#
#
# Recommending 10 products similar to Soaring jkt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Sonar so no t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Special edition pataloha shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Squid t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to S/s island hopper shirt... with threshold 0.5
# -------
# Recommended: L/s island hopper shirt (score:0.8013463830281654)
#
#
# Recommending 10 products similar to S/s pragmatist shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to S/s puckerware shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to S/s stretch t... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Sst jkt... with threshold 0.5
# -------
# Recommending 10 products similar to Stormfront duffel 100... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Stormfront pack... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Stretch polo... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Stretch wading belt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Sub divider... with threshold 0.5
# -------
# Recommended: Great divider (score:0.6735109210642198)
#
#
# Recommending 10 products similar to Surf brim... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Surf sneaker... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Tech web belt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Text logo t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to The more you know t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Three trees shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Torrentshell pants... with threshold 0.5
# -------
# Recommended: Torrentshell pants (score:0.9571830793066652)
#
#
# Recommending 10 products similar to Travel belt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Traverse jkt... with threshold 0.5
# -------
# Recommended: Traverse jkt (score:0.7404923722132086)
#
#
# Recommending 10 products similar to Trout silhouette t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Trucker hat... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Twenty-three's board shorts... with threshold 0.5
# -------
# Recommended: Wavefarer board shorts-21 in. (score:0.5727523409447876)
#
#
# Recommending 10 products similar to Ultra shorts... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Ulw hiking crew socks... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Velocity cap... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Watermaster hip highs... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to World according to bikers t-shir... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to World trout t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Watermaster waders... with threshold 0.5
# -------
# Recommended: Watermaster waders (score:0.9909936969486882)
# Recommended: Watermaster waders (score:0.9908808612929412)
# Recommended: Watermaster waders (score:0.9906486567552875)
# Recommended: Guidewater waders (score:0.6436700211917231)
# Recommended: Guidewater waders (score:0.6385237563121512)
#
#
# Recommending 10 products similar to Watermaster waders... with threshold 0.5
# -------
# Recommended: Watermaster waders (score:0.9909936969486882)
# Recommended: Watermaster waders (score:0.9908178902557145)
# Recommended: Watermaster waders (score:0.9905857004747868)
# Recommended: Guidewater waders (score:0.6436291155990775)
# Recommended: Guidewater waders (score:0.6384831777675349)
#
#
# Recommending 10 products similar to Active hipster... with threshold 0.5
# -------
# Recommended: Active briefs (score:0.5806100752986513)
#
#
# Recommending 10 products similar to Active mesh bra... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to All-out capris... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to All weather training top... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Alpine guide pants... with threshold 0.5
# -------
# Recommended: Alpine guide pants (score:0.8253856759948807)
#
#
# Recommending 10 products similar to Aravis hoody... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Aravis jkt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Astrid tank... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Bandha dress... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Bandha top... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Barely bikini... with threshold 0.5
# -------
# Recommended: Barely hipster (score:0.5833612976590258)
#
#
# Recommending 10 products similar to Better sweater jkt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Birdwalk t-shirt... with threshold 0.5
# -------
# Recommended: Kite town t-shirt (score:0.5029180733443867)
#
#
# Recommending 10 products similar to Borderless capris... with threshold 0.5
# -------
# Recommended: Borderless zip-off pants (score:0.5074841106691931)
#
#
# Recommending 10 products similar to Bouquet t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Butterfly logo t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Cap 1 bottoms... with threshold 0.5
# -------
# Recommended: Cap 1 bottoms (score:0.5651753677668038)
#
#
# Recommending 10 products similar to Cap 1 t-shirt... with threshold 0.5
# -------
# Recommended: Cap 1 graphic t-shirt (score:0.6296589693391987)
# Recommended: Cap 1 t-shirt (score:0.5766557156725726)
# Recommended: Cap 1 scoop (score:0.5748998302238092)
# Recommended: Cap 1 graphic t-shirt (score:0.5374827505943768)
# Recommended: Cap 1 crew (score:0.5341938228481486)
# Recommended: Cap 1 graphic crew (score:0.5122701521239478)
#
#
# Recommending 10 products similar to Cap 2 bottoms... with threshold 0.5
# -------
# Recommended: Cap 2 bottoms (score:0.6151852581876875)
#
#
# Recommending 10 products similar to Cap 2 v-neck... with threshold 0.5
# -------
# Recommended: Cap 2 zip neck (score:0.6175896675347212)
# Recommended: Cap 2 cap sleeve (score:0.5232512984305604)
# Recommended: Cap 2 crew (score:0.5148329784985651)
# Recommended: Cap 2 t-shirt (score:0.5094581638236453)
#
#
# Recommending 10 products similar to Cap 2 zip neck... with threshold 0.5
# -------
# Recommended: Cap 2 zip neck (score:0.6344950850896238)
# Recommended: Cap 2 v-neck (score:0.6175896675347212)
# Recommended: Cap 2 crew (score:0.5308649780944358)
# Recommended: Cap 2 t-shirt (score:0.5295225236280288)
#
#
# Recommending 10 products similar to Cap 4 bottoms... with threshold 0.5
# -------
# Recommended: Cap 4 bottoms (score:0.6573821798739578)
# Recommended: Cap 4 zip neck (score:0.5101184213821071)
#
#
# Recommending 10 products similar to Dala horse t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Ditch the car-ride t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Down sweater... with threshold 0.5
# -------
# Recommended: Down sweater (score:0.8350425162001329)
#
#
# Recommending 10 products similar to El cap jkt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Elsa top... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Elsa tunic... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Gravitee tank... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Guide jkt... with threshold 0.5
# -------
# Recommended: Guide jkt (score:0.8728204455991901)
#
#
# Recommending 10 products similar to Hills t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Inga shorts... with threshold 0.5
# -------
# Recommended: Inga shortie (score:0.6050723396968622)
#
#
# Recommending 10 products similar to Inter-continental capris... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Inter-continental pants... with threshold 0.5
# -------
# Recommended: Inter-continental pants (score:0.9222564277371365)
#
#
# Recommending 10 products similar to Island hemp pants... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Island hemp skirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Island hemp top... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Lithia dress... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Lithia pants... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Lithia skirt... with threshold 0.5
# -------
# Recommended: Kamala skirt (score:0.5768478031212589)
#
#
# Recommending 10 products similar to L/s rashguard... with threshold 0.5
# -------
# Recommended: S/s rashguard (score:0.6668707412901518)
#
#
# Recommending 10 products similar to L/s runshade top... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to M10 jkt... with threshold 0.5
# -------
# Recommended: M10 jkt (score:0.9322179611179894)
#
#
# Recommending 10 products similar to Mandeville hoody... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Margot dress... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Merino 1 graphic t-shirt... with threshold 0.5
# -------
# Recommended: Merino 1 crew (score:0.9137388147141503)
# Recommended: Merino 1 t-shirt (score:0.8822958346850371)
# Recommended: Merino 1 tank (score:0.8268955309642982)
# Recommended: Merino 1 t-shirt (score:0.6983391545795754)
# Recommended: Merino 1 crew (score:0.6168376730361487)
#
#
# Recommending 10 products similar to Merino 1 tank... with threshold 0.5
# -------
# Recommended: Merino 1 crew (score:0.8785539575354709)
# Recommended: Merino 1 t-shirt (score:0.8464071452201953)
# Recommended: Merino 1 graphic t-shirt (score:0.8268955309642982)
# Recommended: Merino 1 t-shirt (score:0.6738398804186714)
# Recommended: Merino 1 crew (score:0.579553880179159)
#
#
# Recommending 10 products similar to Merino 2 crew... with threshold 0.5
# -------
# Recommended: Merino 2 crew (score:0.6568800649940812)
# Recommended: Merino 2 t-shirt (score:0.6466161529611768)
# Recommended: Merino 2 bottoms (score:0.6372928279826015)
# Recommended: Merino 2 bottoms (score:0.6311892715268158)
# Recommended: Merino 2 t-shirt (score:0.6097511363106211)
# Recommended: Merino 2 polo (score:0.5683494594687439)
# Recommended: Merino 1 crew (score:0.5312127545245438)
# Recommended: Merino 2 dress (score:0.5128524595720232)
#
#
# Recommending 10 products similar to Merino 2 dress... with threshold 0.5
# -------
# Recommended: Merino 2 bottoms (score:0.5646632745114899)
# Recommended: Merino 2 bottoms (score:0.547085095024851)
# Recommended: Merino 2 t-shirt (score:0.5396530354364177)
# Recommended: Merino 2 polo (score:0.5266566579166626)
# Recommended: Merino 2 crew (score:0.5256743610109614)
# Recommended: Merino 2 crew (score:0.5128524595720232)
# Recommended: Merino 2 t-shirt (score:0.5028021752115531)
#
#
# Recommending 10 products similar to Micro puff vest... with threshold 0.5
# -------
# Recommended: Micro puff vest (score:0.893856291113022)
#
#
# Recommending 10 products similar to Morning glory capris... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Morning glory cross-back tank... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Multi use shorts... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Multi use skirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Nine trails shorts... with threshold 0.5
# -------
# Recommended: Nine trails shorts (score:0.7427820064015012)
#
#
# Recommending 10 products similar to Nine trails vest... with threshold 0.5
# -------
# Recommended: Nine trails vest (score:0.9712992129880301)
# Recommended: Nine trails jkt (score:0.5450655230186493)
# Recommended: Nine trails jkt (score:0.5342220482257312)
#
#
# Recommending 10 products similar to R2 jkt... with threshold 0.5
# -------
# Recommended: R2 jkt (score:0.8908539128841227)
#
#
# Recommending 10 products similar to Rain shadow jkt... with threshold 0.5
# -------
# Recommended: Rain shadow jkt (score:0.9519519817596891)
#
#
# Recommending 10 products similar to Rock guide pants... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Rock guide shorts... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Serenity tights... with threshold 0.5
# -------
# Recommended: Serenity tights (score:0.8875249876867681)
# Recommended: Serenity capris (score:0.5106675574614346)
#
#
# Recommending 10 products similar to Simple guide jkt... with threshold 0.5
# -------
# Recommended: Simple guide jkt (score:0.9280413287811633)
#
#
# Recommending 10 products similar to Simple guide pants... with threshold 0.5
# -------
# Recommended: Simple guide pants (score:0.6924905991523096)
#
#
# Recommending 10 products similar to Sleeveless a/c shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Solid adour btm... with threshold 0.5
# -------
# Recommended: Print adour btm (score:0.9102963383569895)
# Recommended: Print bayonne btm (score:0.5074700971858782)
# Recommending 10 products similar to Solid betina btm... with threshold 0.5
# -------
# Recommended: Print banded betina btm (score:0.9132682180464679)
#
#
# Recommending 10 products similar to Solid bibiana 1 piece... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Solid bibiana top... with threshold 0.5
# -------
# Recommended: Print bibiana top (score:0.9839873177805977)
#
#
# Recommending 10 products similar to Solimar pants... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Solimar shorts... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to S/s a/c shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to S/s rashguard... with threshold 0.5
# -------
# Recommended: L/s rashguard (score:0.6668707412901518)
# Recommended: S/s rashguard (score:0.5124016137205425)
#
#
# Recommending 10 products similar to S/s sol patrol shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Sun shelter shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Super cali shorts... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Synch vest... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Tranquila capri leggings... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Traverse jkt... with threshold 0.5
# -------
# Recommended: Traverse jkt (score:0.7404923722132086)
#
#
# Recommending 10 products similar to Undercover cami... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Vitaliti dress... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Vitaliti skirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Vitaliti tank... with threshold 0.5
# -------
# Recommended: Vitaliti vee (score:0.5007658308035621)
#
#
# Recommending 10 products similar to Wheat t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Wyoming climbing poster... with threshold 0.5
# -------
# Recommended: Wild steelhead, alaska poster (score:0.7233995251608056)
# Recommended: Going big in b.c. poster (score:0.721611581668574)
# Recommended: Sticks 'n stones morocco poster (score:0.6720724010252346)
# Recommended: Lead an examined life poster (score:0.6411979399045455)
# Recommended: Symmetry w16 poster (score:0.6282349387232767)
# Recommended: Flyfishing the athabasca poster (score:0.6132529577602608)
# Recommended: Traversing auguille d'entreves (score:0.6010792228406163)
#
#
# Recommending 10 products similar to Yosemite essence t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Print bayonne btm... with threshold 0.5
# -------
# Recommended: Print adour btm (score:0.50970674609241)
# Recommended: Solid adour btm (score:0.5074700971858782)
#
#
# Recommending 10 products similar to Print bibiana tankini... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Print bibiana top... with threshold 0.5
# -------
# Recommended: Solid bibiana top (score:0.9839873177805977)
#
#
# Recommending 10 products similar to Print boucau halter top... with threshold 0.5
# -------
# Recommended: Solid boucau halter top (score:0.9848635850376057)
#
#
# Recommending 10 products similar to Print kupala top... with threshold 0.5
# -------
# Recommended: Solid kupala top (score:0.9810475333077001)
#
#
# Recommending 10 products similar to Runshade t-shirt... with threshold 0.5
# -------
# Recommended: Runshade t-shirt (score:0.7112939531590441)
# Recommended: Runshade top (score:0.538621496987378)
#
#
# Recommending 10 products similar to Serenity capris... with threshold 0.5
# -------
# Recommended: Serenity tights (score:0.5122018915529373)
# Recommended: Serenity tights (score:0.5106675574614346)
#
#
# Recommending 10 products similar to Serenity tights... with threshold 0.5
# -------
# Recommended: Serenity tights (score:0.8875249876867681)
# Recommended: Serenity capris (score:0.5122018915529373)
#
#
# Recommending 10 products similar to Simply organic polo... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Simply organic tank... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Simply organic tee... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Simply organic top... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Solid boucau halter top... with threshold 0.5
# -------
# Recommended: Print boucau halter top (score:0.9848635850376057)
#
#
# Recommending 10 products similar to Solid kupala top... with threshold 0.5
# -------
# Recommended: Print kupala top (score:0.9810475333077001)
#
#
# Recommending 10 products similar to Solid paries btm... with threshold 0.5
# -------
# Recommended: Print paries btm (score:0.8099828276092097)
#
#
# Recommending 10 products similar to Solid sunamee btm... with threshold 0.5
# -------
# Recommended: Print sunamee btm (score:0.9691357121396879)
#
#
# Recommending 10 products similar to Solimar skirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Sol patrol shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Sport top... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Meridian board shorts... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Merino 1 crew... with threshold 0.5
# -------
# Recommended: Merino 1 t-shirt (score:0.9186840685666898)
# Recommended: Merino 1 graphic t-shirt (score:0.9137388147141503)
# Recommended: Merino 1 tank (score:0.8785539575354709)
# Recommended: Merino 1 t-shirt (score:0.7559689146017289)
# Recommended: Merino 1 crew (score:0.6385540623104623)
#
#
# Recommending 10 products similar to Print paries btm... with threshold 0.5
# -------
# Recommended: Solid paries btm (score:0.8099828276092097)
#
#
# Recommending 10 products similar to Print sunamee btm... with threshold 0.5
# -------
# Recommended: Solid sunamee btm (score:0.9691357121396879)
#
#
# Recommending 10 products similar to R1 full-zip jkt... with threshold 0.5
# -------
# Recommended: R1 full-zip jkt (score:0.9270271703326702)
#
#
# Recommending 10 products similar to R1 p/o... with threshold 0.5
# -------
# Recommended: R1 p/o (score:0.6950899841063927)
#
#
# Recommending 10 products similar to Merino 1 t-shirt... with threshold 0.5
# -------
# Recommended: Merino 1 crew (score:0.9186840685666898)
# Recommended: Merino 1 graphic t-shirt (score:0.8822958346850371)
# Recommended: Merino 1 tank (score:0.8464071452201953)
# Recommended: Merino 1 t-shirt (score:0.7005765371335269)
# Recommended: Merino 1 crew (score:0.6142503723031506)
#
#
# Recommending 10 products similar to Merino 2 bottoms... with threshold 0.5
# -------
# Recommended: Merino 2 bottoms (score:0.7843682198961149)
# Recommended: Merino 2 crew (score:0.6553237473177826)
# Recommended: Merino 2 t-shirt (score:0.6433303120933126)
# Recommended: Merino 2 crew (score:0.6372928279826015)
# Recommended: Merino 2 polo (score:0.6323953372141051)
# Recommended: Merino 2 t-shirt (score:0.603517786934243)
# Recommended: Merino 2 dress (score:0.5646632745114899)
#
#
# Recommending 10 products similar to Storm light jkt... with threshold 0.5
# -------
# Recommended: Storm light jkt (score:0.9486837053276987)
#
#
# Recommending 10 products similar to Stretch ascent jkt... with threshold 0.5
# -------
# Recommended: Stretch ascent jkt (score:0.9476346709211421)
#
#
# Recommending 10 products similar to Merino 2 t-shirt... with threshold 0.5
# -------
# Recommended: Merino 2 crew (score:0.6466161529611768)
# Recommended: Merino 2 t-shirt (score:0.621345407638338)
# Recommended: Merino 2 crew (score:0.6123734308110917)
# Recommended: Merino 2 bottoms (score:0.603517786934243)
# Recommended: Merino 2 bottoms (score:0.588782900650498)
# Recommended: Merino 2 polo (score:0.5474223305741497)
# Recommended: Merino 2 dress (score:0.5028021752115531)
#
#
# Recommending 10 products similar to Merino 3 pants... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Morning glory dress... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Morning glory skirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Morning glory tights... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Torrentshell jkt... with threshold 0.5
# -------
# Recommended: Torrentshell jkt (score:0.9092014699128355)
#
#
# Recommending 10 products similar to Torrentshell pants... with threshold 0.5
# -------
# Recommended: Torrentshell pants (score:0.9571830793066652)
#
#
# Recommending 10 products similar to Trampoli t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Cap 4 zip neck... with threshold 0.5
# -------
# Recommended: Cap 4 zip neck (score:0.6605420127604072)
# Recommended: Cap 4 bottoms (score:0.5308507649075489)
# Recommended: Cap 4 bottoms (score:0.5101184213821071)
#
#
# Recommending 10 products similar to Corinne dress... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Cotton fleece hoody... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Nano puff p/o... with threshold 0.5
# -------
# Recommended: Nano puff p/o (score:0.7696496429807229)
#
#
# Recommending 10 products similar to Nine trails jkt... with threshold 0.5
# -------
# Recommended: Nine trails jkt (score:0.8664478880889579)
# Recommended: Nine trails vest (score:0.5342220482257312)
# Recommended: Nine trails vest (score:0.5307391030610653)
#
#
# Recommending 10 products similar to Down sweater vest... with threshold 0.5
# -------
# Recommended: Down sweater vest (score:0.814592917925505)
#
#
# Recommending 10 products similar to Drift shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Duway skirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Ester top... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Freedom to roam t-shirt... with threshold 0.5
# -------
# Recommended: Freedom to roam t-shirt (score:0.9812622733833937)
#
#
# Recommending 10 products similar to Girona board shorts... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to North coast t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Owlin around t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Pinback top... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Print adour btm... with threshold 0.5
# -------
# Recommended: Solid adour btm (score:0.9102963383569895)
# Recommended: Print bayonne btm (score:0.50970674609241)
#
#
# Recommending 10 products similar to Hotline top... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Houdini full-zip jkt... with threshold 0.5
# -------
# Recommended: Houdini full-zip jkt (score:0.9376904578333095)
#
#
# Recommending 10 products similar to Inga shortie... with threshold 0.5
# -------
# Recommended: Inga shorts (score:0.6050723396968622)
#
#
# Recommending 10 products similar to Vasana top... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Versatili-tee... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Versatiliti cardi... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Versatiliti tank... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Active boy shorts... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Active briefs... with threshold 0.5
# -------
# Recommended: Active hipster (score:0.5806100752986513)
#
#
# Recommending 10 products similar to Active classic cami... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to All-time shell... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to All-wear capris... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to All weather capris... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Inter-continental pants... with threshold 0.5
# -------
# Recommended: Inter-continental pants (score:0.9222564277371365)
#
#
# Recommending 10 products similar to Inter-continental shorts... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Island hemp dress... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Alpine wind jkt... with threshold 0.5
# -------
# Recommended: Alpine wind jkt (score:0.9550036493156216)
#
#
# Recommending 10 products similar to Aravis 1/4 zip... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Astrid top... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Astrid wrap... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Baggies shorts... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Kamala dress... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Kamala skirt... with threshold 0.5
# -------
# Recommended: Lithia skirt (score:0.5768478031212589)
#
#
# Recommending 10 products similar to Kite town t-shirt... with threshold 0.5
# -------
# Recommended: Birdwalk t-shirt (score:0.5029180733443867)
#
#
# Recommending 10 products similar to Barely bra (a/b)... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Barely everyday bra (b/c)... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Barely hipster... with threshold 0.5
# -------
# Recommended: Barely bikini (score:0.5833612976590258)
#
#
# Recommending 10 products similar to Symmetry w16 poster... with threshold 0.5
# -------
# Recommended: Lead an examined life poster (score:0.7617394854137104)
# Recommended: Flyfishing the athabasca poster (score:0.6544478894872691)
# Recommended: Wyoming climbing poster (score:0.6282349387232767)
# Recommended: Traversing auguille d'entreves (score:0.6075955627011486)
# Recommended: Wild steelhead, alaska poster (score:0.5951729139577726)
# Recommended: Going big in b.c. poster (score:0.5937018934480086)
# Recommended: Sticks 'n stones morocco poster (score:0.550650237747505)
#
#
# Recommending 10 products similar to Synch snap-t... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Synch vest... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Tarpon t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Vitaliti vee... with threshold 0.5
# -------
# Recommended: Vitaliti tank (score:0.5007658308035621)
#
#
# Recommending 10 products similar to Vitalti pants... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Wavefarer board shorts... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Thrift shorts... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Torrentshell jkt... with threshold 0.5
# -------
# Recommended: Torrentshell jkt (score:0.9092014699128355)
#
#
# Recommending 10 products similar to Borderless pants... with threshold 0.5
# -------
# Recommended: Borderless zip-off pants (score:0.5221939633607664)
#
#
# Recommending 10 products similar to Borderless shorts... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Borderless zip-off pants... with threshold 0.5
# -------
# Recommended: Borderless pants (score:0.5221939633607664)
# Recommended: Borderless capris (score:0.5074841106691931)
#
#
# Recommending 10 products similar to Traverse pants... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Traversing auguille d'entreves... with threshold 0.5
# -------
# Recommended: Flyfishing the athabasca poster (score:0.6575417810162206)
# Recommended: Lead an examined life poster (score:0.6171464361249778)
# Recommended: Symmetry w16 poster (score:0.6075955627011486)
# Recommended: Wyoming climbing poster (score:0.6010792228406163)
# ...
# -------
# Recommended: Twenty-three's board shorts (score:0.5727523409447876)
#
#
# Recommending 10 products similar to Wild steelhead, alaska poster... with threshold 0.5
# -------
# Recommended: Wyoming climbing poster (score:0.7233995251608056)
# Recommended: Going big in b.c. poster (score:0.6836354384876687)
# Recommended: Sticks 'n stones morocco poster (score:0.636703348784901)
# Recommended: Lead an examined life poster (score:0.6074537132434243)
# Recommended: Symmetry w16 poster (score:0.5951729139577726)
# Recommended: Flyfishing the athabasca poster (score:0.5845439053271245)
# Recommended: Traversing auguille d'entreves (score:0.569446317813122)
#
#
# Recommending 10 products similar to Wind path t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Marlwalker... with threshold 0.5
# -------
# Recommended: Riverwalker (score:0.6637156228612499)
# Recommended: Riverwalker (score:0.5627754776157905)
# Recommended: Riverwalker (score:0.5563240857708249)
#
#
# Recommending 10 products similar to Marlwalker pants... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Retro grade shorts... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Reversible phone home... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to River shorts... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Hip pack... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Hooded monk sweatshirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Houdini full-zip jkt... with threshold 0.5
# -------
# Recommended: Houdini full-zip jkt (score:0.9376904578333095)
#
#
# Recommending 10 products similar to Merino 2 bottoms... with threshold 0.5
# -------
# Recommended: Merino 2 bottoms (score:0.7843682198961149)
# Recommended: Merino 2 crew (score:0.646671549913041)
# Recommended: Merino 2 t-shirt (score:0.6354414878769347)
# Recommended: Merino 2 crew (score:0.6311892715268158)
# Recommended: Merino 2 polo (score:0.6121277706073268)
# Recommended: Merino 2 t-shirt (score:0.588782900650498)
# Recommended: Merino 2 dress (score:0.547085095024851)
#
#
# Recommending 10 products similar to Merino 2 crew... with threshold 0.5
# -------
# Recommended: Merino 2 t-shirt (score:0.7387583673473282)
# Recommended: Merino 2 crew (score:0.6568800649940812)
# Recommended: Merino 2 bottoms (score:0.6553237473177826)
# Recommended: Merino 2 bottoms (score:0.646671549913041)
# Recommended: Merino 2 t-shirt (score:0.6123734308110917)
# Recommended: Merino 2 polo (score:0.6018782098696162)
# Recommended: Merino 2 dress (score:0.5256743610109614)
#
#
# Recommending 10 products similar to Baggies shorts... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Boardie shorts... with threshold 0.5
# -------
# Recommended: Girl's boardie shorts (score:0.5966928925110491)
#
#
# Recommending 10 products similar to Sun glove... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Sun mask... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Sunshade shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Cap 3 crew... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Duality jkt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Microburst jkt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Micro puff vest... with threshold 0.5
# -------
# Recommended: Micro puff vest (score:0.893856291113022)
#
#
# Recommending 10 products similar to Micro d-luxe cardigan... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Rashguard... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Sunshade hoody... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Riverwalker... with threshold 0.5
# -------
# Recommended: Riverwalker (score:0.8864260498971591)
# Recommended: Riverwalker (score:0.8828362580958543)
# Recommended: Marlwalker (score:0.6637156228612499)
#
#
# Recommending 10 products similar to Freewheeler max... with threshold 0.5
# -------
# Recommended: Freewheeler (score:0.6896990390185027)
#
#
# Recommending 10 products similar to Friction belt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Future of the earth t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Torrentshell pants... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Trim brim hat... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Trucker hat... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Gi ii zip-off pants... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Girl's baggies shorts... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Girl's beach skirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Mlc... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Mlc burrito... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Girl's live simply deer t-shirt... with threshold 0.5
# -------
# Recommended: Girl's live simply seal t-shirt (score:0.9110030924099339)
# Recommended: Live simply guitar t-shirt (score:0.8202636525774637)
# Recommended: '73 logo t-shirt (score:0.8100918892193384)
# Recommended: Flying fish t-shirt (score:0.80672883708396)
# Recommended: Gpiw classic t-shirt (score:0.8018828254625427)
#
#
# Recommending 10 products similar to Girl's live simply seal t-shirt... with threshold 0.5
# -------
# Recommended: Girl's live simply deer t-shirt (score:0.9110030924099339)
# Recommended: Live simply guitar t-shirt (score:0.817401513180821)
# Recommended: '73 logo t-shirt (score:0.8072652420751544)
# Recommended: Flying fish t-shirt (score:0.8039139246106713)
# Recommended: Gpiw classic t-shirt (score:0.7990848221388119)
#
#
# Recommending 10 products similar to Girl's t-back one piece... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Girl's two-piece set... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Lightwire... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Lightwire brief... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Guide jkt... with threshold 0.5
# -------
# Recommended: Guide jkt (score:0.8728204455991901)
#
#
# Recommending 10 products similar to Guidewater duffle... with threshold 0.5
# -------
# Recommended: Guidewater duffle (score:0.6895541163108592)
#
#
# Recommending 10 products similar to Cap 3 bottoms... with threshold 0.5
# -------
# Recommended: Cap 3 bottoms (score:0.66852012077241)
# Recommended: Cap 3 crew (score:0.6368866701188451)
# Recommended: Cap 3 crew (score:0.6055608676833145)
#
#
# Recommending 10 products similar to Cap 3 crew... with threshold 0.5
# -------
# Recommended: Cap 3 crew (score:0.7734953701018475)
# Recommended: Cap 3 zip neck (score:0.6843679481573053)
# Recommended: Cap 3 bottoms (score:0.6368866701188451)
# Recommended: Cap 3 bottoms (score:0.5574677717233013)
#
#
# Recommending 10 products similar to Cap 3 bottoms... with threshold 0.5
# -------
# Recommended: Cap 3 bottoms (score:0.66852012077241)
# Recommended: Cap 3 crew (score:0.5574677717233013)
# Recommended: Cap 3 crew (score:0.5529831864961349)
#
#
# Recommending 10 products similar to Cap 3 crew... with threshold 0.5
# -------
# Recommended: Cap 3 crew (score:0.7734953701018475)
# Recommended: Cap 3 zip neck (score:0.6309802636575091)
# Recommended: Cap 3 bottoms (score:0.6055608676833145)
# Recommended: Cap 3 bottoms (score:0.5529831864961349)
#
#
# Recommending 10 products similar to Guidewater pants... with threshold 0.5
# -------
# Recommended: Guidewater shorts (score:0.7214291304557571)
#
#
# Recommending 10 products similar to Guidewater shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Cap 4 zip neck... with threshold 0.5
# -------
# Recommended: Cap 4 zip neck (score:0.6605420127604072)
#
#
# Recommending 10 products similar to Caribou north wind t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Cerro torre one t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Logo visor... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Long haul runners... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to L/s el ray shirt... with threshold 0.5
# -------
# Recommended: S/s el ray shirt (score:0.7086057466093736)
#
#
# Recommending 10 products similar to Compound cargo pants... with threshold 0.5
# -------
# Recommended: Compound cargo pants (score:0.9405490620389069)
# Recommended: Compound cargo pants (score:0.9325715856217304)
# Recommended: Compound cargo shorts (score:0.5103648088123451)
#
#
# Recommending 10 products similar to Compound cargo shorts... with threshold 0.5
# -------
# Recommended: Compound cargo pants (score:0.5117925102595451)
# Recommended: Compound cargo pants (score:0.5103648088123451)
# Recommended: Compound cargo pants (score:0.5092629518557467)
#
#
# Recommending 10 products similar to Continental pants... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Guidewater waders... with threshold 0.5
# -------
# Recommended: Guidewater waders (score:0.9789276393206185)
# Recommended: Watermaster waders (score:0.6403261325502079)
# Recommended: Watermaster waders (score:0.6385237563121512)
# Recommended: Watermaster waders (score:0.6384831777675349)
# Recommended: Watermaster waders (score:0.6384104793555443)
#
#
# Recommending 10 products similar to Critical mass... with threshold 0.5
# -------
# Recommended: Half mass (score:0.8079611956533355)
#
#
# Recommending 10 products similar to Mw hiking crew socks... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Nano puff p/o... with threshold 0.5
# -------
# Recommended: Nano puff p/o (score:0.7696496429807229)
#
#
# Recommending 10 products similar to Araveto 1/4 zip jkt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Araveto hooded jkt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Araveto jkt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Custodian pants... with threshold 0.5
# -------
# Recommended: Custodian pants (score:0.9035237129098943)
# Recommended: Custodian pants (score:0.9032073991345063)
#
#
# Recommending 10 products similar to Custodian pants... with threshold 0.5
# -------
# Recommended: Custodian pants (score:0.9035237129098943)
# Recommended: Custodian pants (score:0.9020484306816423)
#
#
# Recommending 10 products similar to Daily grind... with threshold 0.5
# -------
# Recommended: Single shot (score:0.6906826033832324)
#
#
# Recommending 10 products similar to Baby baggies apron dress... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Baby baggies shorts... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Baby circus t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Guidewater waders... with threshold 0.5
# -------
# Recommended: Guidewater waders (score:0.9789276393206185)
# Recommended: Watermaster waders (score:0.6453015178828697)
# Recommended: Watermaster waders (score:0.6436700211917231)
# Recommended: Watermaster waders (score:0.6436291155990775)
# Recommended: Watermaster waders (score:0.6434050194063202)
#
#
# Recommending 10 products similar to Baby duality jkt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Baby live simply deer t-shirt... with threshold 0.5
# -------
# Recommended: Baby live simply seal t-shirt (score:0.7371334886173982)
# Recommended: Live simply deer t-shirt (score:0.5116094608869223)
#
#
# Recommending 10 products similar to Baby live simply seal t-shirt... with threshold 0.5
# -------
# Recommended: Baby live simply deer t-shirt (score:0.7371334886173982)
#
#
# Recommending 10 products similar to Double haul... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Down sweater... with threshold 0.5
# -------
# Recommended: Down sweater (score:0.8350425162001329)
# Recommended: Down sweater vest (score:0.5316112056797005)
#
#
# Recommending 10 products similar to Baby synch cardigan... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Baby synch vest... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Baby tag you're it t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to L/s runshade top... with threshold 0.5
# -------
# Recommended: Runshade top (score:0.6118589217273243)
#
#
# Recommending 10 products similar to L/s sol patrol shirt... with threshold 0.5
# -------
# Recommended: S/s sol patrol shirt (score:0.6346209165826874)
#
#
# Recommending 10 products similar to Bimini cap... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Borderless messenger shorts... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Duck pants... with threshold 0.5
# -------
# Recommended: Duck pants (score:0.9152592469250092)
# Recommended: Duck pants (score:0.9129682337046908)
#
#
# Recommending 10 products similar to Duck pants... with threshold 0.5
# -------
# Recommended: Duck pants (score:0.9152592469250092)
# Recommended: Duck pants (score:0.9139073627612257)
#
#
# Recommending 10 products similar to Duck shorts... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Borderless trek pants... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Borderless trek zip-off pants... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Half mass... with threshold 0.5
# -------
# Recommended: Critical mass (score:0.8079611956533355)
#
#
# Recommending 10 products similar to Cap 1 crew... with threshold 0.5
# -------
# Recommended: Cap 1 t-shirt (score:0.5911193687131718)
# Recommended: Cap 1 graphic t-shirt (score:0.5607101445490805)
# Recommended: Cap 1 graphic crew (score:0.5547403166797797)
# Recommended: Cap 1 scoop (score:0.5465249660914739)
# Recommended: Cap 1 t-shirt (score:0.5341938228481486)
#
#
# Recommending 10 products similar to Cap 1 graphic crew... with threshold 0.5
# -------
# Recommended: Cap 1 graphic t-shirt (score:0.6627265635417637)
# Recommended: Cap 1 t-shirt (score:0.6003565514652496)
# Recommended: Cap 1 graphic t-shirt (score:0.572693179926409)
# Recommended: Cap 1 crew (score:0.5547403166797797)
# Recommended: Cap 1 t-shirt (score:0.5122701521239478)
#
#
# Recommending 10 products similar to Fitz roy study t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Flyfishing the athabasca poster... with threshold 0.5
# -------
# Recommended: Traversing auguille d'entreves (score:0.6575417810162206)
# Recommended: Symmetry w16 poster (score:0.6544478894872691)
# Recommended: Lead an examined life poster (score:0.6294065125011518)
# Recommended: Wyoming climbing poster (score:0.6132529577602608)
# Recommended: Wild steelhead, alaska poster (score:0.5845439053271245)
# Recommended: Going big in b.c. poster (score:0.5795434474319056)
# Recommended: Sticks 'n stones morocco poster (score:0.5375184762507964)
#
#
# Recommending 10 products similar to Flying fish 2 t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Freedom to roam t-shirt... with threshold 0.5
# -------
# Recommended: Freedom to roam t-shirt (score:0.9812622733833937)
#
#
# Recommending 10 products similar to '73 logo t-shirt... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Active boxer briefs... with threshold 0.5
# -------
# Recommended: Cap 1 boxer briefs (score:0.5283612680341317)
#
#
# Recommending 10 products similar to Active briefs... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to Cap 2 bottoms... with threshold 0.5
# -------
# Recommended: Cap 2 bottoms (score:0.6151852581876875)
# Recommending 10 products similar to Cap 2 crew... with threshold 0.5
# -------
# Recommended: Cap 2 t-shirt (score:0.7049890803634637)
# Recommended: Cap 2 t-shirt (score:0.6334452370495761)
# Recommended: Cap 2 cap sleeve (score:0.6081146129427677)
# Recommended: Cap 2 zip neck (score:0.567262700882027)
# Recommended: Cap 2 zip neck (score:0.5308649780944358)
# Recommended: Cap 2 v-neck (score:0.5148329784985651)
#
#
# Recommending 10 products similar to All-time shell... with threshold 0.5
# -------
#
#
# Recommending 10 products similar to All-wear cargo shorts... with threshold 0.5
# -------

# %%
data = pd.read_csv('ml-latest-small/movies.csv')
data.info()
print('')
print('')


ratings = pd.read_csv('ml-latest-small/ratings.csv')
del ratings['timestamp']
ratings.info()
print('')
print('')

tags = pd.read_csv('ml-latest-small/tags.csv')
del tags['timestamp']
tags.info()
print('')
print('')

#Joining movies and ratings

movies_data = data.merge(ratings, on = 'movieId', how = 'inner')

#movies_data.info()
#movies_data.isnull().any()
#print(len(movies_data['movieId'].unique().tolist()))

# dropping duplicate  moviId as the recommender system takes input for item(movieId here) and will give recommendation 
# based on tags in single text stream, not multiple rows of duplicate item.

movies_data = movies_data.drop_duplicates(subset = ['movieId'])
print('No of unique moviId in merged datset')
print(len(movies_data['movieId'].unique().tolist()))
print('')
print('')
movies_data.info()
print('')
print('')

#Joining movies_data and tags
tags = tags.drop_duplicates(subset = ['movieId'])
tags.info()

movies_data_tags = movies_data.merge(tags, on ='movieId', how = 'inner')
movies_data_tags.head()

#1554 unique movies with tags
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
# movieId    9742 non-null int64
# title      9742 non-null object
# genres     9742 non-null object
# dtypes: int64(1), object(2)
# memory usage: 228.5+ KB
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 3 columns):
# userId     100836 non-null int64
# movieId    100836 non-null int64
# rating     100836 non-null float64
# dtypes: float64(1), int64(2)
# memory usage: 2.3 MB
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3683 entries, 0 to 3682
# Data columns (total 3 columns):
# userId     3683 non-null int64
# movieId    3683 non-null int64
# tag        3683 non-null object
# dtypes: int64(2), object(1)
# memory usage: 86.4+ KB
#
#
# No of unique moviId in merged datset
# 9724
#
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9724 entries, 0 to 100835
# Data columns (total 5 columns):
# movieId    9724 non-null int64
# title      9724 non-null object
# genres     9724 non-null object
# userId     9724 non-null int64
# rating     9724 non-null float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 455.8+ KB
#
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1572 entries, 0 to 3680
# Data columns (total 3 columns):
# userId     1572 non-null int64
# movieId    1572 non-null int64
# tag        1572 non-null object
# dtypes: int64(2), object(1)
# memory usage: 49.1+ KB
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        5  Father of the Bride Part II (1995)
# 4        7                      Sabrina (1995)
#
#                                         genres  userId_x  rating  userId_y  \
# 0  Adventure|Animation|Children|Comedy|Fantasy         1     4.0       336
# 1                   Adventure|Children|Fantasy         6     4.0        62
# 2                               Comedy|Romance         1     4.0       289
# 3                                       Comedy         6     5.0       474
# 4                               Comedy|Romance         6     4.0       474
#
#          tag
# 0      pixar
# 1    fantasy
# 2      moldy
# 3  pregnancy
# 4     remake

# %% [markdown]
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.metrics.pairwise import linear_kernel
#
# # 1. calculates tf-idf scores for items
# tf = TfidfVectorizer(analyzer='word', ngram_range=(1, 3), min_df=0, stop_words='english')
# tfidf_matrix = tf.fit_transform(movies_data_tags['tag'])
#
#
# # 2. Calculate cosine similarity
# cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)
# results = {}
#
# # 3. Saving results in order of similarity to item i
#
# for idx, row in movies_data_tags.iterrows():
#     similar_indices = cosine_similarities[idx].argsort()[:-100:-1]
#     similar_items = [(cosine_similarities[idx][i], movies_data_tags['tag'][i]) for i in similar_indices]
#
#     results[row['movieId']] = similar_items[1:]
#
# print('Saved')
# print(results)
# #def item(id):
# #return movies_data_tags.loc[movies_data_tags['movieId'] == id]
#
# # 4.a Just reads the results out of the dictionary.
# def recommend(item_id, num, threshold):
#     #print("Recommending " + str(num) + " products similar to " + movies_data_tags['movieId'] == item_id + "...")
#     #print("-------")
#     recs = results[item_id][:num]
#     for rec in recs:
#
#         # A condition can be added to only to print items above a similairty threshold (50% etc.)
#         if(rec[0]>threshold):
#             print("Recommended: " + item(rec[1]) + " (score:" + str(rec[0]) + ")")
#
# # 4. Recommend items similar to item_id and num = number of recommendations with a similarity threshold value
#
#
# recommend(item_id=1, num=5, threshold= 0.3)  # Recommend  5 items similar to item_id 9 with similarity of >30%
# print('')
# print('')
# print('')
# recommend(item_id=3, num=10, threshold= 0.5) # Recommend  10 items similar to item_id 22 with similarity of >50%
